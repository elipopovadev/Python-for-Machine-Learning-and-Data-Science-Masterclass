# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # Project 1: Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 1 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## Data Import and first Inspection

# %% [markdown]
# 1. __Import__ the movies dataset from the CSV file "movies_complete.csv". __Inspect__ the data.

# %% [markdown]
# __Some additional information on Features/Columns__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
df = pd.read_csv('movies_complete.csv', parse_dates = ['release_date'])

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
df.hist(figsize = (20,12), bins = 100)
plt.show()

# %%
df.budget_musd.value_counts(dropna = False).head(20)
# Out:
# NaN      35837
# 5.00       286
# 10.00      258
# 20.00      243
# 2.00       241
# 15.00      226
# 3.00       220
# 25.00      206
# 1.00       195
# 30.00      189
# 4.00       180
# 6.00       173
# 12.00      171
# 40.00      166
# 8.00       155
# 35.00      141
# 0.50       141
# 7.00       137
# 50.00      124
# 1.50       119
# Name: budget_musd, dtype: int64

# %%
df.revenue_musd.value_counts(dropna = False).head(20)
# Out:
# NaN      37306
# 12.00       20
# 10.00       19
# 11.00       19
# 2.00        18
# 6.00        17
# 5.00        14
# 0.50        13
# 8.00        13
# 0.00        12
# 14.00       12
# 7.00        11
# 3.00        10
# 1.00        10
# 20.00       10
# 0.00         9
# 1.50         9
# 4.00         9
# 30.00        8
# 4.10         8
# Name: revenue_musd, dtype: int64

# %%
df.vote_average.value_counts(dropna = False).head(20)
# Out:
# NaN     2614
# 6.00    2421
# 5.00    1969
# 7.00    1859
# 6.50    1705
# 6.30    1583
# 5.50    1369
# 5.80    1358
# 6.40    1343
# 6.70    1328
# 6.80    1316
# 6.10    1274
# 6.60    1250
# 6.20    1240
# 5.90    1189
# 5.30    1068
# 5.70    1039
# 6.90    1029
# 5.60     994
# 7.30     987
# Name: vote_average, dtype: int64

# %%
df.vote_count.value_counts(dropna = False)
# Out:
# 1.00       3186
# 2.00       3056
# 3.00       2729
# 0.00       2614
# 4.00       2442
#            ...
# 2755.00       1
# 1187.00       1
# 4200.00       1
# 3322.00       1
# 2712.00       1
# Name: vote_count, Length: 1820, dtype: int64

# %%
df.describe(include = 'object')
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        44691                   20284  42586                  4463
# unique       41605                   20171   4044                  1691
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            11                       7   4935                    29
#
#        original_language       production_companies      production_countries  \
# count              44681                      33356                     38835
# unique                89                      22537                      2377
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               31755                        741                     17723
#
#                                     overview spoken_languages  \
# count                                  43740            41094
# unique                                 43715             1828
# ...

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# 2. __Filter__ the Dataset and __find the best/worst n Movies__ with the

# %% [markdown]
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %%
df.budget_musd.fillna(0, inplace = True)
df.vote_count.fillna(0, inplace = True)

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
df.sort_values(by=['revenue_musd'], ascending=[False]).head(5)[['title', 'revenue_musd']]
# Out:
#                               title  revenue_musd
# 14448                        Avatar       2787.97
# 26265  Star Wars: The Force Awakens       2068.22
# 1620                        Titanic       1845.03
# 17669                  The Avengers       1519.56
# 24812                Jurassic World       1513.53

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
df.sort_values(by=['budget_musd'], ascending=[False]).head(5)[['title', 'budget_musd']]
# Out:
#                                              title  budget_musd
# 16986  Pirates of the Caribbean: On Stranger Tides       380.00
# 11743     Pirates of the Caribbean: At World's End       300.00
# 26268                      Avengers: Age of Ultron       280.00
# 10985                             Superman Returns       270.00
# 44095                Transformers: The Last Knight       260.00

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
df['profit_diff'] = df['revenue_musd'] - df['budget_musd']
df.sort_values(by=['profit_diff'], ascending=[False]).head(5)[['title', 'profit_diff']]
# Out:
#                               title  profit_diff
# 14448                        Avatar      2550.97
# 26265  Star Wars: The Force Awakens      1823.22
# 1620                        Titanic      1645.03
# 24812                Jurassic World      1363.53
# 28501                     Furious 7      1316.25

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
df.sort_values(by=['profit_diff']).head(5)[['title', 'profit_diff']]
# Out:
#                                              title  profit_diff
# 20959                              The Lone Ranger      -165.71
# 7164                                     The Alamo      -119.18
# 16659                              Mars Needs Moms      -111.01
# 43611  Valerian and the City of a Thousand Planets      -107.45
# 2684                              The 13th Warrior       -98.30

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
df_above_10_budget = df.copy().loc[df['budget_musd']>=10]
df_above_10_budget['ROI'] = df_above_10_budget['revenue_musd'] / df_above_10_budget['budget_musd']
df_above_10_budget.sort_values(by=['ROI'], ascending=[False]).head(5)[['title', 'ROI']]
# Out:
#                             title   ROI
# 1055   E.T. the Extra-Terrestrial 75.52
# 255                     Star Wars 70.49
# 588                  Pretty Woman 33.07
# 18300            The Intouchables 32.81
# 1144      The Empire Strikes Back 29.91

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
df_above_10_budget.sort_values(by=['ROI']).head(5)[['title', 'ROI']]
# Out:
#                  title  ROI
# 6955   Chasing Liberty 0.00
# 8041       The Cookout 0.00
# 17381         Deadfall 0.00
# 6678        In the Cut 0.00
# 20015    The Samaritan 0.00

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
df.sort_values(by=['vote_count'], ascending = [False]).head(5)[['title', 'vote_count']]
# Out:
#                  title  vote_count
# 15368        Inception    14075.00
# 12396  The Dark Knight    12269.00
# 14448           Avatar    12114.00
# 17669     The Avengers    12000.00
# 26272         Deadpool    11444.00

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
df_above_10_ratings = df.loc[df['vote_count']>=10]
df_above_10_ratings.sort_values(by=['vote_average'], ascending = [False]).head(5)[['title', 'vote_average']]
# Out:
#                                                    title  vote_average
# 20787  As I Was Moving Ahead Occasionally I Saw Brief...          9.50
# 42626                                    Planet Earth II          9.50
# 18462                                      The Civil War          9.20
# 10233                        Dilwale Dulhania Le Jayenge          9.10
# 42822                                             Cosmos          9.10

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
df_above_10_ratings.sort_values(by=['vote_average']).head(5)[['title', 'vote_average']]
# Out:
#                                  title  vote_average
# 41602             Call Me by Your Name          0.00
# 30618   Extinction: Nature Has Evolved          0.00
# 43576  How to Talk to Girls at Parties          0.00
# 25418                      Santa Claus          1.60
# 7030          The Beast of Yucca Flats          1.60

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
df.sort_values(by=['popularity'], ascending = False).head(5)[['title', 'popularity']]
# Out:
#                       title  popularity
# 30330               Minions      547.49
# 32927          Wonder Woman      294.34
# 41556  Beauty and the Beast      287.25
# 42940           Baby Driver      228.03
# 24187            Big Hero 6      213.85

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# 3. __Filter__ the Dataset for movies that meet the following conditions:

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %%
mask1 = df['genres'].str.contains('Science Fiction')
mask2 = df['genres'].str.contains('Action')
mask3 = df['cast'].str.contains('Bruce Willis')
df.loc[mask1 & mask2 & mask3, ['title', 'genres', 'cast', 'vote_average']].sort_values(by=['vote_average'],ascending = False)
# Out:
#                        title  \
# 1448       The Fifth Element
# 19218                 Looper
# 1786              Armageddon
# 14135             Surrogates
# 20333  G.I. Joe: Retaliation
# 27619                   Vice
#
#                                                   genres  \
# 1448   Adventure|Fantasy|Action|Thriller|Science Fiction
# 19218                    Action|Thriller|Science Fiction
# 1786           Action|Thriller|Science Fiction|Adventure
# 14135                    Action|Science Fiction|Thriller
# 20333          Adventure|Action|Science Fiction|Thriller
# 27619          Thriller|Science Fiction|Action|Adventure
#
#                                                     cast  vote_average
# 1448   Bruce Willis|Gary Oldman|Ian Holm|Milla Jovovi...          7.30
# 19218  Joseph Gordon-Levitt|Bruce Willis|Emily Blunt|...          6.60
# 1786   Bruce Willis|Billy Bob Thornton|Ben Affleck|Li...          6.50
# ...

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %%
mask1 = df['cast'].str.contains('Uma Thurman')
mask2 = df['director'].str.contains('Quentin Tarantino')
df.loc[mask1 & mask2, ['title', 'cast', 'director', 'runtime']].sort_values(by=['runtime'], ascending = True)
# Out:
#                   title                                               cast  \
# 6667  Kill Bill: Vol. 1  Uma Thurman|Lucy Liu|Vivica A. Fox|Daryl Hanna...
# 7208  Kill Bill: Vol. 2  Uma Thurman|David Carradine|Daryl Hannah|Micha...
# 291        Pulp Fiction  John Travolta|Samuel L. Jackson|Uma Thurman|Br...
#
#                director  runtime
# 6667  Quentin Tarantino   111.00
# 7208  Quentin Tarantino   136.00
# 291   Quentin Tarantino   154.00

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %%
mask1 = df['release_date'].dt.date.astype(str) >= '2010'
mask2 = df['release_date'].dt.date.astype(str) <= '2015'
mask3 = df['production_companies'].str.contains('Pixar')
df.loc[mask1 & mask2 & mask3,['title','production_companies','release_date', 'revenue_musd']].sort_values(by=['revenue_musd'],ascending = False)
# Out:
#                             title  \
# 15236                 Toy Story 3
# 20888         Monsters University
# 17220                      Cars 2
# 18900                       Brave
# 16392                 Day & Night
# 21694           The Blue Umbrella
# 21697        Toy Story of Terror!
# 22489                     La luna
# 24252           Hawaiian Vacation
# 24254                   Small Fry
# 25515             Partysaurus Rex
# 25516        The Legend of Mor'du
# 25517  Toy Story That Time Forgot
# 40259                   Air Mater
#
#                                production_companies release_date  revenue_musd
# 15236  Walt Disney Pictures|Pixar Animation Studios   2010-06-16       1066.97
# 20888  Walt Disney Pictures|Pixar Animation Studios   2013-06-20        743.56
# 17220  Walt Disney Pictures|Pixar Animation Studios   2011-06-11        559.85
# 18900  Walt Disney Pictures|Pixar Animation Studios   2012-06-21        538.98
# ...

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
mask1 = df['genres'].str.contains('Action')
mask2 = df['genres'].str.contains('Thriller')
mask3 = df['spoken_languages'].str.contains('English')
mask4 = df['vote_average'] >= 7.5
df.loc[(mask1 | mask2) & mask3 & mask4,['title', 'genres', 'release_date']].sort_values(by=['release_date'], ascending = False)
# Out:
#                                 title  \
# 43941                         Dunkirk
# 42624               The Book of Henry
# 26273  Guardians of the Galaxy Vol. 2
# 43467                     Revengeance
# 41506                           Logan
# ...                               ...
# 25954                     Night Court
# 11135                   The Music Box
# 8268                         Scarface
# 2879                      The General
# 34547        Bardelys the Magnificent
#
#                                         genres release_date
# 43941        Action|Drama|History|Thriller|War   2017-07-19
# 42624                     Thriller|Drama|Crime   2017-06-16
# 26273  Action|Adventure|Comedy|Science Fiction   2017-04-19
# 43467                  Comedy|Action|Animation   2017-04-05
# 41506             Action|Drama|Science Fiction   2017-02-28
# ...                                        ...          ...
# 25954                     Crime|Drama|Thriller   1932-06-04
# ...

# %% [markdown]
# ## Are Franchises more successful?

# %% [markdown]
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:

# %% [markdown]
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %% [markdown]
# hint: use groupby()

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
df['Franchise'] = df.belongs_to_collection.notna()

# %%
df['Franchise']
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: Franchise, Length: 44691, dtype: bool

# %%
df['Franchise'].value_counts()
# Out:
# False    40228
# True      4463
# Name: Franchise, dtype: int64

# %%
df.groupby('Franchise').revenue_musd.mean()
# Out:
# Franchise
# False    44.74
# True    165.71
# Name: revenue_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %%
df['ROI'] = df['revenue_musd'] / df['budget_musd']

# %%
df.groupby('Franchise').ROI.median()
# Out:
# Franchise
# False   2.99
# True    4.65
# Name: ROI, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
df.groupby('Franchise').budget_musd.mean()
# Out:
# Franchise
# False    3.26
# True    13.58
# Name: budget_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
df.groupby('Franchise').popularity.mean()
# Out:
# Franchise
# False   2.59
# True    6.25
# Name: popularity, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
df.groupby('Franchise').vote_average.mean()
# Out:
# Franchise
# False   6.01
# True    5.96
# Name: vote_average, dtype: float64

# %%
df.groupby('Franchise').agg({'budget_musd' : 'mean', 'revenue_musd':
                             'mean', 'vote_average' : 'mean', 'popularity' : 'mean',
                            'ROI' : 'median', 'vote_count' : 'mean'})
# Out:
#            budget_musd  revenue_musd  vote_average  popularity  ROI  \
# Franchise
# False             3.26         44.74          6.01        2.59 2.99
# True             13.58        165.71          5.96        6.25 4.65
#
#            vote_count
# Franchise
# False           78.29
# True           412.39

# %% [markdown]
# ## Most Successful Franchises

# %% [markdown]
# 5. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %%
df.belongs_to_collection.value_counts()
# Out:
# The Bowery Boys                  29
# Totò Collection                  27
# Zatôichi: The Blind Swordsman    26
# James Bond Collection            26
# The Carry On Collection          25
#                                  ..
# Salt and Pepper Collection        1
# Deadpool Collection               1
# Ant-Man Collection                1
# Elvira Collection                 1
# Red Lotus Collection              1
# Name: belongs_to_collection, Length: 1691, dtype: int64

# %%
franchises = df.groupby('belongs_to_collection').agg({'title' : 'count', 'budget_musd' : ['sum','mean'], 'revenue_musd':
                             ['sum','mean'], 'vote_average' : 'mean', 'popularity' : 'mean',
                            'ROI' : 'median', 'vote_count' : 'mean'})

# %%
franchises
# Out:
#                                      title budget_musd       revenue_musd  \
#                                      count         sum  mean          sum
# belongs_to_collection
# ... Has Fallen Collection                2      130.00 65.00       366.78
# 00 Schneider Filmreihe                   1        0.00  0.00         0.00
# 08/15 Collection                         1        0.00  0.00         0.00
# 100 Girls Collection                     2        0.00  0.00         0.00
# 101 Dalmatians (Animated) Collection     2        4.00  2.00       215.88
# ...                                    ...         ...   ...          ...
# Сказки Чуковского                        1        0.00  0.00         0.00
# Чебурашка и крокодил Гена                1        0.00  0.00         0.00
# Что Творят мужчины! (Коллекция)          2        2.00  1.00         0.00
# 男はつらいよ シリーズ                              3        0.00  0.00         0.00
# ...

# %%
franchises.nlargest(20, ('title', 'count'))
# Out:
#                                        title budget_musd       revenue_musd  \
#                                        count         sum  mean          sum
# belongs_to_collection
# The Bowery Boys                           29        0.00  0.00         0.00
# Totò Collection                           27        0.00  0.00         0.00
# James Bond Collection                     26     1539.65 59.22      7106.97
# Zatôichi: The Blind Swordsman             26        0.00  0.00         0.00
# The Carry On Collection                   25        0.00  0.00         0.00
# Charlie Chan (Sidney Toler) Collection    21        0.00  0.00         0.00
# Pokémon Collection                        20      250.72 12.54       601.87
# Godzilla (Showa) Collection               16        2.81  0.18         0.00
# Charlie Chan (Warner Oland) Collection    15        0.00  0.00         0.00
# Dragon Ball Z (Movie) Collection          15        5.00  0.33       112.12
# ...

# %%
franchises.nlargest(20, ('budget_musd', 'sum'))
# Out:
#                                         title budget_musd        revenue_musd  \
#                                         count         sum   mean          sum
# belongs_to_collection
# James Bond Collection                      26     1539.65  59.22      7106.97
# Harry Potter Collection                     8     1280.00 160.00      7707.37
# Pirates of the Caribbean Collection         5     1250.00 250.00      4521.58
# The Fast and the Furious Collection         8     1009.00 126.12      5125.10
# X-Men Collection                            6      983.00 163.83      2808.83
# Transformers Collection                     5      965.00 193.00      4366.10
# Star Wars Collection                        8      854.35 106.79      7434.49
# The Hobbit Collection                       3      750.00 250.00      2935.52
# The Terminator Collection                   5      661.40 132.28      1845.33
# Mission: Impossible Collection              5      650.00 130.00      2778.98
# ...

# %%
franchises.nlargest(20, ('budget_musd', 'mean'))
# Out:
#                                         title budget_musd        revenue_musd  \
#                                         count         sum   mean          sum
# belongs_to_collection
# Pirates of the Caribbean Collection         5     1250.00 250.00      4521.58
# The Avengers Collection                     2      500.00 250.00      2924.96
# The Hobbit Collection                       3      750.00 250.00      2935.52
# Man of Steel Collection                     2      475.00 237.50      1536.11
# Avatar Collection                           1      237.00 237.00      2787.97
# The Amazing Spider-Man Collection           2      415.00 207.50      1457.93
# World War Z Collection                      1      200.00 200.00       531.87
# Spider-Man Collection                       3      597.00 199.00      2496.35
# The Dark Knight Collection                  3      585.00 195.00      2463.72
# Transformers Collection                     5      965.00 193.00      4366.10
# ...

# %%
franchises.nlargest(20, ('revenue_musd', 'sum'))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# Star Wars Collection                    8      854.35 106.79      7434.49
# James Bond Collection                  26     1539.65  59.22      7106.97
# The Fast and the Furious Collection     8     1009.00 126.12      5125.10
# Pirates of the Caribbean Collection     5     1250.00 250.00      4521.58
# Transformers Collection                 5      965.00 193.00      4366.10
# Despicable Me Collection                6      299.00  49.83      3691.07
# The Twilight Collection                 5      385.00  77.00      3342.11
# Ice Age Collection                      5      429.00  85.80      3216.71
# Jurassic Park Collection                4      379.00  94.75      3031.48
# ...

# %%
franchises.nlargest(20, ('revenue_musd', 'mean'))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# Avatar Collection                       1      237.00 237.00      2787.97
# The Avengers Collection                 2      500.00 250.00      2924.96
# Frozen Collection                       2      150.00  75.00      1274.22
# Finding Nemo Collection                 2      294.00 147.00      1968.91
# The Hobbit Collection                   3      750.00 250.00      2935.52
# The Lord of the Rings Collection        3      266.00  88.67      2916.54
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# Star Wars Collection                    8      854.35 106.79      7434.49
# Despicable Me Collection                6      299.00  49.83      3691.07
# Pirates of the Caribbean Collection     5     1250.00 250.00      4521.58
# ...

# %%
franchises.nlargest(20, ('vote_average', 'mean'))
# Out:
#                                     title budget_musd       revenue_musd  \
#                                     count         sum  mean          sum
# belongs_to_collection
# Argo Collection                         1        0.00  0.00         0.00
# Bloodfight                              1        0.00  0.00         0.00
# Dreileben                               1        0.00  0.00         0.00
# Kenji Misumi's Trilogy of the Sword     1        0.00  0.00         0.00
# Алиса в стране чудес (Коллекция)        1        0.00  0.00         0.00
# We Were Here                            2        0.00  0.00         0.00
# Kizumonogatari                          3        0.00  0.00         0.00
# Glass Tiger collection                  1        0.00  0.00         0.00
# OSS 117 The Original Saga               1        0.00  0.00         0.00
# Spirits' Homecoming Collection          1        0.00  0.00         0.00
# ...

# %%
franchises[franchises[('vote_count', 'mean')] >= 1000].nlargest(20, ('vote_average', 'mean'))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# The Lord of the Rings Collection        3      266.00  88.67      2916.54
# The Godfather Collection                3       73.00  24.33       429.38
# Blade Runner Collection                 1       28.00  28.00        33.14
# The Man With No Name Collection         3        2.00   0.67        35.50
# The Dark Knight Collection              3      585.00 195.00      2463.72
# Guardians of the Galaxy Collection      2      370.00 185.00      1636.74
# Kill Bill Collection                    2       60.00  30.00       333.11
# Kingsman Collection                     1       81.00  81.00       414.35
# How to Train Your Dragon Collection     2      310.00 155.00      1104.00
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# ...

# %% [markdown]
# ## Most Successful Directors

# %% [markdown]
# 6. __Find__ the __most successful Directors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %%
df.director.value_counts()
# Out:
# John Ford           66
# Michael Curtiz      65
# Werner Herzog       54
# Alfred Hitchcock    53
# Georges Méliès      49
#                     ..
# Jason Osder          1
# John Alan Simon      1
# Jennifer Kent        1
# Hiroshi Ando         1
# Daisy Asquith        1
# Name: director, Length: 17349, dtype: int64

# %%
df_directors = df.director.value_counts().to_frame()
df_directors
# Out:
#                   director
# John Ford               66
# Michael Curtiz          65
# Werner Herzog           54
# Alfred Hitchcock        53
# Georges Méliès          49
# ...                    ...
# Jason Osder              1
# John Alan Simon          1
# Jennifer Kent            1
# Hiroshi Ando             1
# Daisy Asquith            1
#
# [17349 rows x 1 columns]

# %%
df_directors = df_directors.reset_index()
df_directors
# Out:
#                   index  director
# 0             John Ford        66
# 1        Michael Curtiz        65
# 2         Werner Herzog        54
# 3      Alfred Hitchcock        53
# 4        Georges Méliès        49
# ...                 ...       ...
# 17344       Jason Osder         1
# 17345   John Alan Simon         1
# 17346     Jennifer Kent         1
# 17347      Hiroshi Ando         1
# 17348     Daisy Asquith         1
#
# [17349 rows x 2 columns]

# %%
df_directors = df_directors.rename(columns = {'index' : 'director', 'director' : 'count'})
df_directors
# Out:
#                director  count
# 0             John Ford     66
# 1        Michael Curtiz     65
# 2         Werner Herzog     54
# 3      Alfred Hitchcock     53
# 4        Georges Méliès     49
# ...                 ...    ...
# 17344       Jason Osder      1
# 17345   John Alan Simon      1
# 17346     Jennifer Kent      1
# 17347      Hiroshi Ando      1
# 17348     Daisy Asquith      1
#
# [17349 rows x 2 columns]

# %%
df_directors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17349 entries, 0 to 17348
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   director  17349 non-null  object
#  1   count     17349 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 271.2+ KB

# %%
most_active_directors = df_directors.nlargest(20, ('count'))

# %%
sns.set(rc={'figure.figsize':(10.7,8.7)})
plt.xticks(rotation=90)
sns.barplot(data=most_active_directors, x = 'director', y = 'count', color = 'blue', edgecolor = 'red', linewidth = 3)
plt.show()

# %%
directors = df.groupby('director').agg({'title' : 'count', 'revenue_musd' : ['sum', 'mean'], 'vote_count' : 'mean'})
directors
# Out:
#                     title revenue_musd      vote_count
#                     count          sum mean       mean
# director
#  Dale Trevillion\t      2         0.00  NaN       2.00
#  Davide Manuli          1         0.00  NaN      10.00
#  E.W. Swackhamer        1         0.00  NaN       5.00
#  Vitaliy Vorobyov       1         0.00  NaN       3.00
#  Yeon Sang-Ho           4         2.13 2.13     259.75
# ...                   ...          ...  ...        ...
# Ярополк Лапшин          1         0.00  NaN       1.00
# پیمان معادی             1         0.00  NaN       2.00
# 塩谷 直義                   1         0.00  NaN      40.00
# 杰森·莫玛                   1         0.00  NaN      28.00
# 진모영                     1         0.00  NaN       6.00
#
# [17349 rows x 4 columns]

# %%
directors.nlargest(20, ('title', 'count'))
# Out:
#                    title revenue_musd        vote_count
#                    count          sum   mean       mean
# director
# John Ford             66        85.17   8.52      33.48
# Michael Curtiz        65        37.82   7.56      38.09
# Werner Herzog         54        24.57   6.14      46.59
# Alfred Hitchcock      53       250.11  11.91     240.98
# Georges Méliès        49         0.00    NaN      16.86
# Woody Allen           49       993.97  36.81     316.57
# Jean-Luc Godard       46         0.87   0.14      32.13
# Sidney Lumet          46       294.52  22.66     114.93
# Charlie Chaplin       44        26.52   4.42      85.18
# Raoul Walsh           43         1.21   1.21      13.56
# William A. Wellman    42         0.00    NaN      12.48
# Henry Hathaway        41        24.95   8.32      17.76
# Richard Thorpe        40         0.00    NaN       6.85
# Ingmar Bergman        39        11.50   5.75      66.69
# Martin Scorsese       39      1990.98 104.79     911.31
# ...

# %%
directors.nlargest(20, ('revenue_musd', 'sum'))
# Out:
#                   title revenue_musd        vote_count
#                   count          sum   mean       mean
# director
# Steven Spielberg     33      9256.62 308.55    1886.85
# Peter Jackson        13      6528.24 593.48    3659.31
# Michael Bay          13      6437.47 495.19    2212.85
# James Cameron        11      5900.61 737.58    3066.91
# David Yates           9      5334.56 889.09    3450.67
# Christopher Nolan    11      4747.41 474.74    6122.18
# Robert Zemeckis      19      4138.23 243.43    1982.42
# Tim Burton           21      4032.92 224.05    1758.19
# Ridley Scott         24      3917.53 170.33    1795.12
# Chris Columbus       15      3866.84 297.45    1760.87
# Roland Emmerich      16      3798.40 345.31    1255.31
# Ron Howard           26      3714.15 195.48     820.96
# J.J. Abrams           5      3579.22 715.84    4320.80
# Gore Verbinski       10      3575.34 357.53    2535.40
# George Lucas          7      3341.55 556.93    2884.29
# ...

# %%
directors.nlargest(20, ('revenue_musd', 'mean'))
# Out:
#                  title revenue_musd         vote_count
#                  count          sum    mean       mean
# director
# Chris Buck           2      1274.22 1274.22    3035.00
# Lee Unkrich          1      1066.97 1066.97    4710.00
# David Yates          9      5334.56  889.09    3450.67
# Chris Renaud         2       875.46  875.46    1790.50
# Kyle Balda           5      2525.63  841.88    1602.60
# Byron Howard         3      1615.58  807.79    2921.00
# Chris Miller         1       798.96  798.96    2355.00
# Roger Allers         3       788.24  788.24    1859.67
# Tim Miller           1       783.11  783.11   11444.00
# Robert Stromberg     1       758.54  758.54    4607.00
# Pierre Coffin        2      1514.28  757.14    5662.00
# Dan Scanlon          1       743.56  743.56    3622.00
# Joss Whedon          5      2963.83  740.96    4109.60
# James Cameron       11      5900.61  737.58    3066.91
# Pete Docter          4      2155.53  718.51    5019.00
# ...

# %%
directors.nlargest(20, ('vote_count', 'mean'))
# Out:
#                   title revenue_musd         vote_count
#                   count          sum    mean       mean
# director
# Tim Miller            1       783.11  783.11   11444.00
# Christopher Nolan    11      4747.41  474.74    6122.18
# Pierre Coffin         2      1514.28  757.14    5662.00
# Pete Docter           4      2155.53  718.51    5019.00
# Alex Garland          1        36.87   36.87    4862.00
# Andrew Stanton        4      2774.36  693.59    4808.50
# Lee Unkrich           1      1066.97 1066.97    4710.00
# Rich Moore            1       471.22  471.22    4656.00
# Lana Wachowski        2       470.53  235.26    4641.00
# Robert Stromberg      1       758.54  758.54    4607.00
# Quentin Tarantino    10      1526.67  169.63    4591.00
# Wes Ball              2       659.58  329.79    4344.00
# J.J. Abrams           5      3579.22  715.84    4320.80
# Chad Stahelski        2       260.30  130.15    4211.50
# Joss Whedon           5      2963.83  740.96    4109.60
# ...

# %% [markdown]
# ## Most Succesful Actors

# %%
df.set_index('id', inplace = True)
df.head()
# Out:
#                              title  \
# id
# 862                      Toy Story
# 8844                       Jumanji
# 15602             Grumpier Old Men
# 31357            Waiting to Exhale
# 11862  Father of the Bride Part II
#
#                                                  tagline release_date  \
# id
# 862                                                  NaN   1995-10-30
# 8844           Roll the dice and unleash the excitement!   1995-12-15
# 15602  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 31357  Friends are the people who let you be yourself...   1995-12-22
# 11862  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                          genres           belongs_to_collection  \
# id
# 862     Animation|Comedy|Family            Toy Story Collection
# 8844   Adventure|Fantasy|Family                             NaN
# 15602            Romance|Comedy       Grumpy Old Men Collection
# ...

# %%
df['cast']
# Out:
# id
# 862       Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 8844      Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 15602     Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...
# 31357     Whitney Houston|Angela Bassett|Loretta Devine|...
# 11862     Steve Martin|Diane Keaton|Martin Short|Kimberl...
#                                 ...
# 439050              Leila Hatami|Kourosh Tahami|Elham Korda
# 111109    Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...
# 67758     Erika Eleniak|Adam Baldwin|Julie du Page|James...
# 227506    Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...
# 461257                                                  NaN
# Name: cast, Length: 44691, dtype: object

# %%
df_actors = df['cast'].str.split('|', expand=True)
df_actors
# Out:
#                      0                  1               2    \
# id
# 862            Tom Hanks          Tim Allen     Don Rickles
# 8844      Robin Williams      Jonathan Hyde   Kirsten Dunst
# 15602     Walter Matthau        Jack Lemmon     Ann-Margret
# 31357    Whitney Houston     Angela Bassett  Loretta Devine
# 11862       Steve Martin       Diane Keaton    Martin Short
# ...                  ...                ...             ...
# 439050      Leila Hatami     Kourosh Tahami     Elham Korda
# 111109      Angel Aquino        Perry Dizon   Hazel Orencio
# 67758      Erika Eleniak       Adam Baldwin   Julie du Page
# 227506  Iwan Mosschuchin  Nathalie Lissenko    Pavel Pavlov
# 461257               NaN                NaN             NaN
#
#                               3               4                  5    \
# id
# 862                    Jim Varney   Wallace Shawn  John Ratzenberger
# 8844               Bradley Pierce     Bonnie Hunt      Bebe Neuwirth
# ...

# %%
df_actors_last = df_actors.stack().reset_index(level = 1, drop = True).to_frame()
df_actors_last
# Out:
#                         0
# id
# 862             Tom Hanks
# 862             Tim Allen
# 862           Don Rickles
# 862            Jim Varney
# 862         Wallace Shawn
# ...                   ...
# 227506   Iwan Mosschuchin
# 227506  Nathalie Lissenko
# 227506       Pavel Pavlov
# 227506  Aleksandr Chabrov
# 227506        Vera Orlova
#
# [557703 rows x 1 columns]

# %%
df_actors_last.columns = ['Actor']
df_actors_last.head(20)
# Out:
#                   Actor
# id
# 862           Tom Hanks
# 862           Tim Allen
# 862         Don Rickles
# 862          Jim Varney
# 862       Wallace Shawn
# 862   John Ratzenberger
# 862         Annie Potts
# 862         John Morris
# 862     Erik von Detten
# 862      Laurie Metcalf
# 862        R. Lee Ermey
# 862       Sarah Freeman
# 862       Penn Jillette
# 8844     Robin Williams
# 8844      Jonathan Hyde
# 8844      Kirsten Dunst
# 8844     Bradley Pierce
# 8844        Bonnie Hunt
# 8844      Bebe Neuwirth
# 8844   David Alan Grier

# %%
df_actors_last = df_actors_last.merge(df[['title', 'revenue_musd', 'vote_average', 'popularity']],
                                      how = 'left', left_index = True, right_index = True)
df_actors_last
# Out:
#                      Actor                            title  revenue_musd  \
# id
# 2              Turo Pajala                            Ariel           NaN
# 2         Susanna Haavisto                            Ariel           NaN
# 2          Matti Pellonpää                            Ariel           NaN
# 2             Eetu Hilkamo                            Ariel           NaN
# 3          Matti Pellonpää              Shadows in Paradise           NaN
# ...                    ...                              ...           ...
# 469172      Vasco Sequeira  Manuel on the Island of Wonders           NaN
# 469172     Armanda Bacelar  Manuel on the Island of Wonders           NaN
# 469172     Rafael de Sousa  Manuel on the Island of Wonders           NaN
# 469172  José Antônio Gomes  Manuel on the Island of Wonders           NaN
# 469172       Isabel Branco  Manuel on the Island of Wonders           NaN
#
#         vote_average  popularity
# id
# 2               7.10        3.86
# ...

# %%
df_actors_last.Actor.nunique()
# Out:
# 201501

# %%
df_actors_last.Actor.unique()
# Out:
# array(['Turo Pajala', 'Susanna Haavisto', 'Matti Pellonpää', ...,
#        'Armanda Bacelar', 'Rafael de Sousa', 'José Antônio Gomes'],
#       dtype=object)

# %%
plt.figure(figsize=(12,8))
df_actors_last.Actor.value_counts().head(20).plot(kind = 'bar', fontsize = 15)
plt.title('Most Active Actors', fontsize = 20)
plt.show()

# %%
agg_actors = df_actors_last.groupby('Actor').agg({'title' : 'count', 
                                     'revenue_musd': ['sum','mean'],
                                     'vote_average' : 'mean', 
                                     'popularity' : 'mean',
                                      'Actor' : 'count'})
agg_actors
# Out:
#                       title revenue_musd        vote_average popularity Actor
#                       count          sum   mean         mean       mean count
# Actor
# \tCheung Chi-Sing         1         0.00    NaN         5.90       3.05     1
# \tDouglas Hegdahl         1         0.00    NaN         4.00       0.15     1
# \tRobert Osth             1         0.00    NaN         6.00       1.81     1
# \tYip Chun                2         0.00    NaN         6.75       1.80     2
#   Jorge de los Reyes      1         0.00    NaN         8.10       3.47     1
# ...                     ...          ...    ...          ...        ...   ...
# 长泽雅美                     11         0.35   0.35         6.40       2.82    11
# 陳美貞                       1        83.06  83.06         7.00       6.49     1
# 高桥一生                      8       333.11 166.55         6.74       9.10     8
# 강계열                       1         0.00    NaN         6.00       0.44     1
# ...

# %%
agg_actors.nlargest(10, ('revenue_musd', 'sum'))
# Out:
#                   title revenue_musd        vote_average popularity Actor
#                   count          sum   mean         mean       mean count
# Actor
# Stan Lee             48     19414.96 647.17         6.51      29.94    48
# Samuel L. Jackson   122     17109.62 213.87         6.27      11.70   122
# Warwick Davis        34     13256.03 662.80         6.29      13.09    34
# Frank Welker        107     13044.15 326.10         6.31       9.57   107
# John Ratzenberger    46     12596.13 449.86         6.48      10.96    46
# Jess Harnell         35     12234.61 611.73         6.44      10.92    35
# Hugo Weaving         40     11027.58 459.48         6.47      10.97    40
# Ian McKellen         44     11015.59 478.94         6.35      15.45    44
# Johnny Depp          69     10653.76 217.42         6.44      12.38    69
# Alan Rickman         45     10612.63 353.75         6.72      10.40    45

# %%
agg_actors.nlargest(10, ('title', 'count'))['title', 'count'].plot(kind = 'bar', fontsize = 20)
# Out:
# <AxesSubplot: xlabel='Actor'>
