# %%
import yfinance as yahooFinance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
pd.set_option('display.max_rows', None)

# %%
ticker = "BMW.DE"

# %% [markdown]
#  ## 1.Stock Information

# %%
stock = yahooFinance.Ticker(ticker)

# %%
stock_info = stock.info
stock_info
# Out:
# {'address1': 'Petuelring 130',
#  'city': 'Munich',
#  'zip': '80809',
#  'country': 'Germany',
#  'phone': '49 89 382 0',
#  'fax': '49 0 89 382 14661',
#  'website': 'https://www.bmwgroup.com',
#  'industry': 'Auto Manufacturers',
#  'industryKey': 'auto-manufacturers',
#  'industryDisp': 'Auto Manufacturers',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %%
market_cap = stock_info['marketCap']
market_cap
# Out:
# 43829948416

# %%
exchange = stock_info['exchange']
exchange
# Out:
# 'GER'

# %%
averageVolume = stock_info['averageVolume']
averageVolume
# Out:
# 1059222

# %%
averageVolume10days = stock_info['averageVolume10days']
averageVolume10days
# Out:
# 820843

# %%
currentPrice = stock_info['currentPrice']
currentPrice
# Out:
# 69.08

# %%
fiftyDayAverage_stockPrice = stock_info['fiftyDayAverage']
fiftyDayAverage_stockPrice
# Out:
# 76.5612

# %%
twoHundredDayAverage_StockPrice = stock_info['twoHundredDayAverage']
twoHundredDayAverage_StockPrice
# Out:
# 91.75345

# %%
forwardPE = stock_info['forwardPE']
forwardPE
# Out:
# 4.2563157

# %%
trailingPE = stock_info['trailingPE']
trailingPE
# Out:
# 4.176542

# %%
priceToBook = stock_info['priceToBook']
priceToBook
# Out:
# 0.47691372

# %%
priceToSalesTrailing12Months = stock_info['priceToSalesTrailing12Months']
priceToSalesTrailing12Months
# Out:
# 0.28280303

# %%
currentRatio = stock_info['currentRatio']
currentRatio
# Out:
# 1.103

# %%
forwardEps = stock_info['forwardEps']
forwardEps
# Out:
# 16.23

# %%
trailingEps = stock_info['trailingEps']
trailingEps
# Out:
# 16.54

# %%
earningsGrowth = stock_info['earningsGrowth']
earningsGrowth
# Out:
# -0.052

# %%
beta = stock_info['beta']
beta
# Out:
# 1.076

# %%
recommendationKey = stock_info['recommendationKey']
recommendationKey
# Out:
# 'hold'

# %%
shareHolderRightsRisk = stock_info['shareHolderRightsRisk']
shareHolderRightsRisk
# Out:
# 10

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
#  ## 2.Holders

# %%
try:
  print(stock.major_holders)
except Exception:
  print("An exception occurred")
# Out:
# An exception occurred

# %%
try:
  print(stock.institutional_holders)
except Exception:
  print("An exception occurred")
# Out:
#   Date Reported                Holder  pctHeld  Shares     Value
# 0    2023-12-31  Pacer Advisors, Inc.   0.0006  349092  35181491

# %%
try:
  print(stock.mutualfund_holders)
except:
  print("An exception occurred")
# Out:
#   Date Reported                                             Holder  pctHeld  \
# 0    2023-10-31  Vanguard International Stock Index-Total Intl ...   0.0070
# 1    2023-12-31                         Oakmark International Fund   0.0068
# 2    2023-12-31  Vanguard Tax Managed Fund-Vanguard Developed M...   0.0042
# 3    2023-11-30                 Vanguard International Growth Fund   0.0036
# 4    2024-01-31                         iShares Core MSCI EAFE ETF   0.0030
# 5    2024-01-31                              iShares MSCI Eafe ETF   0.0017
# 6    2024-01-31                     DFA International Value Series   0.0016
# 7    2024-01-31                                Vanguard/Windsor II   0.0016
# 8    2024-01-31                  Fidelity International Index Fund   0.0015
# 9    2024-01-31                        iShares MSCI Eafe Value ETF   0.0012
#
#     Shares      Value
# 0  4232478  370892047
# 1  4115579  414768051
# 2  2531260  255100382
# 3  2168590  207295518
# ...

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# ## 3.Actions - Dividends & Stock Splits

# %%
stock.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2000-05-17 00:00:00+02:00       0.40           0.0
# 2001-05-16 00:00:00+02:00       0.46           0.0
# 2002-05-17 00:00:00+02:00       0.52           0.0
# 2003-05-16 00:00:00+02:00       0.52           0.0
# 2004-05-14 00:00:00+02:00       0.58           0.0
# 2005-05-13 00:00:00+02:00       0.62           0.0
# 2006-05-17 00:00:00+02:00       0.64           0.0
# 2007-05-16 00:00:00+02:00       0.70           0.0
# 2008-05-09 00:00:00+02:00       1.06           0.0
# 2009-05-15 00:00:00+02:00       0.30           0.0
# 2010-05-19 00:00:00+02:00       0.30           0.0
# 2011-05-13 00:00:00+02:00       1.30           0.0
# 2012-05-17 00:00:00+02:00       2.30           0.0
# 2013-05-15 00:00:00+02:00       2.50           0.0
# 2014-05-16 00:00:00+02:00       2.60           0.0
# 2015-05-14 00:00:00+02:00       2.90           0.0
# 2016-05-13 00:00:00+02:00       3.20           0.0
# ...

# %%
df_dividends = pd.DataFrame(stock.dividends)
df_new = df_dividends.groupby(['Date']).agg({'Dividends': 'sum'}).reset_index()
df_new
# Out:
#                         Date  Dividends
# 0  2000-05-17 00:00:00+02:00       0.40
# 1  2001-05-16 00:00:00+02:00       0.46
# 2  2002-05-17 00:00:00+02:00       0.52
# 3  2003-05-16 00:00:00+02:00       0.52
# 4  2004-05-14 00:00:00+02:00       0.58
# 5  2005-05-13 00:00:00+02:00       0.62
# 6  2006-05-17 00:00:00+02:00       0.64
# 7  2007-05-16 00:00:00+02:00       0.70
# 8  2008-05-09 00:00:00+02:00       1.06
# 9  2009-05-15 00:00:00+02:00       0.30
# 10 2010-05-19 00:00:00+02:00       0.30
# 11 2011-05-13 00:00:00+02:00       1.30
# 12 2012-05-17 00:00:00+02:00       2.30
# 13 2013-05-15 00:00:00+02:00       2.50
# 14 2014-05-16 00:00:00+02:00       2.60
# 15 2015-05-14 00:00:00+02:00       2.90
# 16 2016-05-13 00:00:00+02:00       3.20
# 17 2017-05-12 00:00:00+02:00       3.50
# 18 2018-05-18 00:00:00+02:00       4.00
# 19 2019-05-17 00:00:00+02:00       3.50
# 20 2020-05-15 00:00:00+02:00       2.50
# 21 2021-05-13 00:00:00+02:00       1.90
# ...

# %%
df_new['Date_in_Datetime'] = pd.to_datetime(df_new['Date'])
df_new['Year'] = df_new['Date_in_Datetime'].dt.year
df_new
# Out:
#                         Date  Dividends          Date_in_Datetime  Year
# 0  2000-05-17 00:00:00+02:00       0.40 2000-05-17 00:00:00+02:00  2000
# 1  2001-05-16 00:00:00+02:00       0.46 2001-05-16 00:00:00+02:00  2001
# 2  2002-05-17 00:00:00+02:00       0.52 2002-05-17 00:00:00+02:00  2002
# 3  2003-05-16 00:00:00+02:00       0.52 2003-05-16 00:00:00+02:00  2003
# 4  2004-05-14 00:00:00+02:00       0.58 2004-05-14 00:00:00+02:00  2004
# 5  2005-05-13 00:00:00+02:00       0.62 2005-05-13 00:00:00+02:00  2005
# 6  2006-05-17 00:00:00+02:00       0.64 2006-05-17 00:00:00+02:00  2006
# 7  2007-05-16 00:00:00+02:00       0.70 2007-05-16 00:00:00+02:00  2007
# 8  2008-05-09 00:00:00+02:00       1.06 2008-05-09 00:00:00+02:00  2008
# 9  2009-05-15 00:00:00+02:00       0.30 2009-05-15 00:00:00+02:00  2009
# 10 2010-05-19 00:00:00+02:00       0.30 2010-05-19 00:00:00+02:00  2010
# 11 2011-05-13 00:00:00+02:00       1.30 2011-05-13 00:00:00+02:00  2011
# ...

# %%
df_converted= df_new.groupby(['Year']).agg({'Dividends': 'sum'}).reset_index()
df_converted
# Out:
#     Year  Dividends
# 0   2000       0.40
# 1   2001       0.46
# 2   2002       0.52
# 3   2003       0.52
# 4   2004       0.58
# 5   2005       0.62
# 6   2006       0.64
# 7   2007       0.70
# 8   2008       1.06
# 9   2009       0.30
# 10  2010       0.30
# 11  2011       1.30
# 12  2012       2.30
# 13  2013       2.50
# 14  2014       2.60
# 15  2015       2.90
# 16  2016       3.20
# 17  2017       3.50
# 18  2018       4.00
# 19  2019       3.50
# 20  2020       2.50
# 21  2021       3.80
# 22  2022       5.80
# 23  2023       8.50
# 24  2024       6.00

# %%
plt.style.use("ggplot")
plt.figure(figsize=(12, 8))
plt.bar(df_converted['Year'], df_converted['Dividends'], color = 'b')

# Set x-axis ticks to display every year between 1 and rotate them
plt.xticks(np.arange(df_converted['Year'].min(), df_converted['Year'].max() + 1, 1), rotation=45)

plt.xlabel('Year')
plt.ylabel('Total Dividends')
plt.title('Dividends by Year')

# Show grid and plot
plt.grid(True)
plt.show()

# %%
# Define the style and figure size
plt.style.use("ggplot")
plt.figure(figsize=(12, 8))

# Plot the data
plt.plot(df_converted['Year'], df_converted['Dividends'], marker='o', color='b')

# Set x-axis ticks to display every year between 1 and rotate them
plt.xticks(np.arange(df_converted['Year'].min(), df_converted['Year'].max() + 1, 1), rotation=45)

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Total Dividends')
plt.title('Dividends by Year')

# Show grid and plot
plt.grid(True)
plt.show()

# %%
dividend_Yield = stock_info['dividendYield']
dividend_Yield
# Out:
# 0.082600005

# %%
trailingAnnualDividendYield = stock_info['trailingAnnualDividendYield']
trailingAnnualDividendYield
# Out:
# 0.082621865

# %%
try:
    avg_DvidendYield_5_years = stock_info['fiveYearAvgDividendYield']
    print(avg_DvidendYield_5_years)
except Exception:
    print("An exception occurred")
# Out:
# 5.58

# %%
payoutRatio = stock_info['payoutRatio']
payoutRatio
# Out:
# 0.3628

# %%
stock.splits
# Out:
# Series([], Name: Stock Splits, dtype: float64)

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# ## 4.Balance Sheet Statement

# %%
balance_sheet_df = pd.DataFrame(stock.balance_sheet)
balance_sheet_df
# Out:
#                                                         2023-12-31  \
# Ordinary Shares Number                                 638716075.0
# Share Issued                                           638716075.0
# Net Debt                                             51682000000.0
# Total Debt                                           71548000000.0
# Tangible Book Value                                  69574000000.0
# Invested Capital                                    158605000000.0
# Working Capital                                       7971000000.0
# Net Tangible Assets                                  69574000000.0
# Capital Lease Obligations                             2539000000.0
# Common Stock Equity                                  89596000000.0
# Total Capitalization                                133165000000.0
# Total Equity Gross Minority Interest                 92923000000.0
# Minority Interest                                     3327000000.0
# ...

# %%
balance_sheet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, Ordinary Shares Number to Cash And Cash Equivalents
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   2023-12-31 00:00:00  72 non-null     object
#  1   2022-12-31 00:00:00  73 non-null     object
#  2   2021-12-31 00:00:00  73 non-null     object
#  3   2020-12-31 00:00:00  71 non-null     object
#  4   2019-12-31 00:00:00  5 non-null      object
# dtypes: object(5)
# memory usage: 3.6+ KB

# %% [markdown]
# # balance_df_liabilities

# %%
balance_df_liabilities = balance_sheet_df.loc[['Current Liabilities','Long Term Debt', 'Total Non Current Liabilities Net Minority Interest','Total Liabilities Net Minority Interest']]
balance_df_liabilities
# Out:
#                                                         2023-12-31  \
# Current Liabilities                                  87001000000.0
# Long Term Debt                                       43569000000.0
# Total Non Current Liabilities Net Minority Inte...   70966000000.0
# Total Liabilities Net Minority Interest             157967000000.0
#
#                                                         2022-12-31  \
# Current Liabilities                                  84421000000.0
# Long Term Debt                                       43983000000.0
# Total Non Current Liabilities Net Minority Inte...   71217000000.0
# Total Liabilities Net Minority Interest             155638000000.0
#
#                                                         2021-12-31  \
# Current Liabilities                                  76466000000.0
# Long Term Debt                                       55724000000.0
# Total Non Current Liabilities Net Minority Inte...   77929000000.0
# ...

# %%
for index, row in balance_df_liabilities.iterrows():
    plt.figure(figsize=(4, 3))  # Create a new figure for each row
    row.plot(kind= 'bar', color = 'b' )  # Plot a histogram (use 'bar' for row-wise data)
    plt.title(f'{index}')
    plt.xlabel('Columns')
    plt.ylabel('Values')
    plt.show()  # Display the histogram

# %%
transposed_df_liabilities = balance_df_liabilities.T
transposed_df_liabilities
# Out:
#            Current Liabilities Long Term Debt  \
# 2023-12-31       87001000000.0  43569000000.0
# 2022-12-31       84421000000.0  43983000000.0
# 2021-12-31       76466000000.0  55724000000.0
# 2020-12-31       71963000000.0  60438000000.0
# 2019-12-31                 NaN            NaN
#
#            Total Non Current Liabilities Net Minority Interest  \
# 2023-12-31                                      70966000000.0
# 2022-12-31                                      71217000000.0
# 2021-12-31                                      77929000000.0
# 2020-12-31                                      83175000000.0
# 2019-12-31                                                NaN
#
#            Total Liabilities Net Minority Interest
# 2023-12-31                          157967000000.0
# 2022-12-31                          155638000000.0
# 2021-12-31                          154395000000.0
# 2020-12-31                          155138000000.0
# ...

# %%
transposed_df_liabilities.plot(kind = 'line',marker='o',subplots= True, figsize=(10,8), sharex= False, sharey=False)
plt.tight_layout()
plt.show()

# %%
balance_df_liabilities_percentage = balance_df_liabilities.pct_change(axis='columns', fill_method=None) * 100
balance_df_liabilities_percentage
# Out:
#                                                    2023-12-31 2022-12-31  \
# Current Liabilities                                       NaN  -2.965483
# Long Term Debt                                            NaN   0.950217
# Total Non Current Liabilities Net Minority Inte...        NaN    0.35369
# Total Liabilities Net Minority Interest                   NaN  -1.474359
#
#                                                    2021-12-31 2020-12-31  \
# Current Liabilities                                 -9.423011  -5.888892
# Long Term Debt                                      26.694405   8.459551
# Total Non Current Liabilities Net Minority Inte...   9.424716   6.731769
# Total Liabilities Net Minority Interest             -0.798648   0.481233
#
#                                                    2019-12-31
# Current Liabilities                                       NaN
# Long Term Debt                                            NaN
# ...

# %%
# Plot each row
for idx, row in balance_df_liabilities_percentage.iterrows():
    row.plot(kind='bar', title=f"{idx} Percentage Differences Between Consecutive Values")
    plt.ylabel("Percentage Change (%)")
    plt.xlabel("Columns")
    plt.axhline(0, color='black', linewidth=0.5)  # Add a line at 0% for reference
    plt.show()

# %% [markdown]
# # balance_df_assets

# %%
balance_df_assets = balance_sheet_df.loc[['Cash And Cash Equivalents','Gross Accounts Receivable', 'Inventory','Current Assets', 'Net PPE','Goodwill And Other Intangible Assets', 'Total Non Current Assets']]
balance_df_assets
# Out:
#                                           2023-12-31      2022-12-31  \
# Cash And Cash Equivalents              17327000000.0   16870000000.0
# Gross Accounts Receivable              41070000000.0   39526000000.0
# Inventory                              23708000000.0   19746000000.0
# Current Assets                         94972000000.0   92204000000.0
# Net PPE                                78384000000.0   74946000000.0
# Goodwill And Other Intangible Assets   20022000000.0   21776000000.0
# Total Non Current Assets              155918000000.0  154722000000.0
#
#                                           2021-12-31      2020-12-31  \
# Cash And Cash Equivalents              16009000000.0   13537000000.0
# Gross Accounts Receivable              37998000000.0   38597000000.0
# Inventory                              15539000000.0   14393000000.0
# Current Assets                         86173000000.0   81807000000.0
# ...

# %%
for index, row in balance_df_assets.iterrows():
    plt.figure(figsize=(4, 3))  # Create a new figure for each row
    row.plot(kind= 'bar', color = 'b' )  # Plot a histogram (use 'bar' for row-wise data)
    plt.title(f'{index}')
    plt.xlabel('Columns')
    plt.ylabel('Values')
    plt.show()  # Display the histogram

# %%
transposed_df_assets = balance_df_assets.T
transposed_df_assets_percentage = transposed_df_assets.div(transposed_df_assets.sum(axis=1).replace(0, 1), axis=0) * 100
transposed_df_assets_percentage
# Out:
#            Cash And Cash Equivalents Gross Accounts Receivable Inventory  \
# 2023-12-31                  4.016449                  9.520145  5.495583
# 2022-12-31                  4.018676                   9.41566   4.70378
# 2021-12-31                  4.222417                 10.022076  4.098454
# 2020-12-31                  3.766849                 10.740124  4.005042
# 2019-12-31                       NaN                       NaN       NaN
#
#            Current Assets    Net PPE Goodwill And Other Intangible Assets  \
# 2023-12-31      22.014784  18.169638                             4.641158
# 2022-12-31      21.964315  17.853212                             5.187356
# 2021-12-31      22.728364   17.69517                              3.42351
# 2020-12-31      22.763877  17.765714                             3.434324
# 2019-12-31            NaN        NaN                                  NaN
#
#            Total Non Current Assets
# 2023-12-31                36.142244
# ...

# %%
transposed_df_assets.plot(subplots= True, marker = 'o', figsize=(10,12), sharex= False, sharey=False)
plt.tight_layout()
plt.show()

# %%
balance_df_assets_percentage = balance_df_assets.pct_change(axis='columns', fill_method=None) * 100
balance_df_assets_percentage
# Out:
#                                      2023-12-31 2022-12-31 2021-12-31  \
# Cash And Cash Equivalents                   NaN  -2.637502  -5.103734
# Gross Accounts Receivable                   NaN  -3.759435   -3.86581
# Inventory                                   NaN -16.711659 -21.305581
# Current Assets                              NaN  -2.914543  -6.540931
# Net PPE                                     NaN  -4.386099 -10.482214
# Goodwill And Other Intangible Assets        NaN   8.760364 -40.393093
# Total Non Current Assets                    NaN   -0.76707  -7.347371
#
#                                      2020-12-31 2019-12-31
# Cash And Cash Equivalents            -15.441314        NaN
# Gross Accounts Receivable              1.576399        NaN
# Inventory                             -7.374992        NaN
# Current Assets                        -5.066552        NaN
# Net PPE                               -4.836786        NaN
# ...

# %%
# Plot each row
for idx, row in balance_df_assets_percentage.iterrows():
    row.plot(kind='bar', title=f"{idx} Percentage Differences Between Consecutive Values")
    plt.ylabel("Percentage Change (%)")
    plt.xlabel("Columns")
    plt.axhline(0, color='black', linewidth=0.5)  # Add a line at 0% for reference
    plt.show()

# %% [markdown]
# ### 4.1 Balance Sheet for the last year with Vertical Analysis

# %%
balance_sheet_df_last = pd.DataFrame(balance_sheet_df.iloc[:,0])
balance_sheet_df_last
# Out:
#                                                         2023-12-31
# Ordinary Shares Number                                 638716075.0
# Share Issued                                           638716075.0
# Net Debt                                             51682000000.0
# Total Debt                                           71548000000.0
# Tangible Book Value                                  69574000000.0
# Invested Capital                                    158605000000.0
# Working Capital                                       7971000000.0
# Net Tangible Assets                                  69574000000.0
# Capital Lease Obligations                             2539000000.0
# Common Stock Equity                                  89596000000.0
# Total Capitalization                                133165000000.0
# Total Equity Gross Minority Interest                 92923000000.0
# Minority Interest                                     3327000000.0
# ...

# %%
total_assets = balance_sheet_df_last.loc['Total Assets'].values[0]
balance_sheet_df_last['Percentage from Total Assets/Liabilities'] = balance_sheet_df_last.iloc[:, [0]] / total_assets * 100
balance_sheet_df_last
# Out:
#                                                    2023-12-31 00:00:00  \
# Ordinary Shares Number                                     638716075.0
# Share Issued                                               638716075.0
# Net Debt                                                 51682000000.0
# Total Debt                                               71548000000.0
# Tangible Book Value                                      69574000000.0
# Invested Capital                                        158605000000.0
# Working Capital                                           7971000000.0
# Net Tangible Assets                                      69574000000.0
# Capital Lease Obligations                                 2539000000.0
# Common Stock Equity                                      89596000000.0
# Total Capitalization                                    133165000000.0
# Total Equity Gross Minority Interest                     92923000000.0
# ...

# %% [markdown]
# ### 4.2 Balance Sheet for the previous year with Vertical Analysis

# %%
balance_sheet_df = pd.DataFrame(stock.balance_sheet)
balance_sheet_df_prev = pd.DataFrame(balance_sheet_df.iloc[:,1])
balance_sheet_df_prev
# Out:
#                                                         2022-12-31
# Ordinary Shares Number                                 662839475.0
# Share Issued                                           662839475.0
# Net Debt                                             51927000000.0
# Total Debt                                           71561000000.0
# Tangible Book Value                                  65349000000.0
# Invested Capital                                    155922000000.0
# Working Capital                                       7783000000.0
# Net Tangible Assets                                  65349000000.0
# Capital Lease Obligations                             2764000000.0
# Common Stock Equity                                  87125000000.0
# Total Capitalization                                131108000000.0
# Total Equity Gross Minority Interest                 91288000000.0
# Minority Interest                                     4163000000.0
# ...

# %%
total_assets = balance_sheet_df_prev.loc['Total Assets'].values[0]
balance_sheet_df_prev['Percentage from Total Assets/Liabilities'] = balance_sheet_df_prev.iloc[:, [0]] / total_assets * 100
balance_sheet_df_prev
# Out:
#                                                    2022-12-31 00:00:00  \
# Ordinary Shares Number                                     662839475.0
# Share Issued                                               662839475.0
# Net Debt                                                 51927000000.0
# Total Debt                                               71561000000.0
# Tangible Book Value                                      65349000000.0
# Invested Capital                                        155922000000.0
# Working Capital                                           7783000000.0
# Net Tangible Assets                                      65349000000.0
# Capital Lease Obligations                                 2764000000.0
# Common Stock Equity                                      87125000000.0
# Total Capitalization                                    131108000000.0
# Total Equity Gross Minority Interest                     91288000000.0
# ...

# %% [markdown]
# ### 4.3 Balance Sheet for the last two years with Vertical Analysis

# %%
df_concat_balance = pd.concat([balance_sheet_df_last, balance_sheet_df_prev], axis=1)
df_concat_balance
# Out:
#                                                    2023-12-31 00:00:00  \
# Ordinary Shares Number                                     638716075.0
# Share Issued                                               638716075.0
# Net Debt                                                 51682000000.0
# Total Debt                                               71548000000.0
# Tangible Book Value                                      69574000000.0
# Invested Capital                                        158605000000.0
# Working Capital                                           7971000000.0
# Net Tangible Assets                                      69574000000.0
# Capital Lease Obligations                                 2539000000.0
# Common Stock Equity                                      89596000000.0
# Total Capitalization                                    133165000000.0
# Total Equity Gross Minority Interest                     92923000000.0
# ...

# %%
df_concat_balance.loc['Current Assets']
# Out:
# 2023-12-31 00:00:00                         94972000000.0
# Percentage from Total Assets/Liabilities         37.85404
# 2022-12-31 00:00:00                         92204000000.0
# Percentage from Total Assets/Liabilities        37.340742
# Name: Current Assets, dtype: object

# %%
df_concat_balance.loc['Total Non Current Assets']
# Out:
# 2023-12-31 00:00:00                         155918000000.0
# Percentage from Total Assets/Liabilities          62.14596
# 2022-12-31 00:00:00                         154722000000.0
# Percentage from Total Assets/Liabilities         62.659258
# Name: Total Non Current Assets, dtype: object

# %%
df_concat_balance.loc['Current Liabilities']
# Out:
# 2023-12-31 00:00:00                         87001000000.0
# Percentage from Total Assets/Liabilities         34.67695
# 2022-12-31 00:00:00                         84421000000.0
# Percentage from Total Assets/Liabilities        34.188785
# Name: Current Liabilities, dtype: object

# %%
df_concat_balance.loc['Total Non Current Liabilities Net Minority Interest']
# Out:
# 2023-12-31 00:00:00                         70966000000.0
# Percentage from Total Assets/Liabilities        28.285703
# 2022-12-31 00:00:00                         71217000000.0
# Percentage from Total Assets/Liabilities        28.841434
# Name: Total Non Current Liabilities Net Minority Interest, dtype: object

# %%
df_concat_balance.loc["Long Term Debt"]
# Out:
# 2023-12-31 00:00:00                         43569000000.0
# Percentage from Total Assets/Liabilities        17.365778
# 2022-12-31 00:00:00                         43983000000.0
# Percentage from Total Assets/Liabilities        17.812219
# Name: Long Term Debt, dtype: object

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# ## 5.Cash Flow Statement

# %%
cash_flow = stock.cash_flow
cash_flow
# Out:
#                                                 2023-12-31     2022-12-31  \
# Free Cash Flow                                6661000000.0  14473000000.0
# Repurchase Of Capital Stock                  -1222000000.0  -1278000000.0
# Repayment Of Debt                           -22430000000.0 -26102000000.0
# Issuance Of Debt                             20633000000.0  16050000000.0
# Issuance Of Capital Stock                              0.0     85000000.0
# Capital Expenditure                         -10881000000.0  -9050000000.0
# End Cash Position                            17327000000.0  16870000000.0
# Other Cash Adjustment Outside Changein Cash            NaN            NaN
# Beginning Cash Position                      16870000000.0  16009000000.0
# Effect Of Exchange Rate Changes               -705000000.0    104000000.0
# Changes In Cash                               1162000000.0    757000000.0
# Other Cash Adjustment Inside Changein Cash      27000000.0    -10000000.0
# ...

# %% [markdown]
# # cash_flow_df_bar

# %%
cash_flow_df_bar = cash_flow.loc[['Operating Cash Flow','Investing Cash Flow', 'Financing Cash Flow','Long Term Debt Payments']]
cash_flow_df_bar
# Out:
#                             2023-12-31     2022-12-31     2021-12-31  \
# Operating Cash Flow      17542000000.0  23523000000.0  15914000000.0
# Investing Cash Flow      -9548000000.0  -4772000000.0  -6400000000.0
# Financing Cash Flow      -6859000000.0 -17984000000.0  -6735000000.0
# Long Term Debt Payments -22430000000.0 -26102000000.0 -26434000000.0
#
#                              2020-12-31 2019-12-31
# Operating Cash Flow       13251000000.0        NaN
# Investing Cash Flow       -3636000000.0        NaN
# Financing Cash Flow       -8254000000.0        NaN
# Long Term Debt Payments -171532000000.0        NaN

# %%
for index, row in cash_flow_df_bar.iterrows():
    plt.figure(figsize=(6, 3))  # Create a new figure for each row
    row.plot(kind= 'bar', color = 'b' )  # Plot a histogram (use 'bar' for row-wise data)
    plt.title(f'{index}')
    plt.xlabel('Columns')
    plt.ylabel('Values')
    plt.show()  # Display the histogram

# %%
transposed_cash_flow_df_bar = cash_flow_df_bar.T
transposed_cash_flow_df_bar.plot(kind='line', marker = 'o',subplots=True, figsize=(10,12), sharex= False, sharey=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.1 Operating Cash Flow

# %%
cash_flow.loc['Operating Cash Flow']
# Out:
# 2023-12-31    17542000000.0
# 2022-12-31    23523000000.0
# 2021-12-31    15914000000.0
# 2020-12-31    13251000000.0
# 2019-12-31              NaN
# Name: Operating Cash Flow, dtype: object

# %% [markdown]
# ### 5.2 Investing Cash Flow

# %%
cash_flow.loc['Investing Cash Flow']
# Out:
# 2023-12-31   -9548000000.0
# 2022-12-31   -4772000000.0
# 2021-12-31   -6400000000.0
# 2020-12-31   -3636000000.0
# 2019-12-31             NaN
# Name: Investing Cash Flow, dtype: object

# %% [markdown]
# ### 5.3 Financing Cash Flow

# %%
cash_flow.loc['Financing Cash Flow']
# Out:
# 2023-12-31    -6859000000.0
# 2022-12-31   -17984000000.0
# 2021-12-31    -6735000000.0
# 2020-12-31    -8254000000.0
# 2019-12-31              NaN
# Name: Financing Cash Flow, dtype: object

# %% [markdown]
# ### 5.4 Long Term Debt Payments

# %%
cash_flow.loc['Long Term Debt Payments']
# Out:
# 2023-12-31    -22430000000.0
# 2022-12-31    -26102000000.0
# 2021-12-31    -26434000000.0
# 2020-12-31   -171532000000.0
# 2019-12-31               NaN
# Name: Long Term Debt Payments, dtype: object

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# ## 6.Income Statement

# %%
income_statement_df = pd.DataFrame(stock.income_stmt)
income_statement_df
# Out:
#                                                         2023-12-31  \
# Tax Effect Of Unusual Items                             -6336000.0
# Tax Rate For Calcs                                           0.288
# Normalized EBITDA                                    26748000000.0
# Total Unusual Items                                    -22000000.0
# Total Unusual Items Excluding Goodwill                 -22000000.0
# Net Income From Continuing Operation Net Minori...   11290000000.0
# Reconciled Depreciation                               8974000000.0
# Reconciled Cost Of Revenue                          125809000000.0
# EBITDA                                               26726000000.0
# EBIT                                                 17752000000.0
# Net Interest Income                                     45000000.0
# Interest Expense                                       656000000.0
# Interest Income                                        701000000.0
# ...

# %% [markdown]
# # income_statement_df_hist

# %%
income_statement_df_hist = income_statement_df.loc[['Total Revenue', 'Cost Of Revenue',
                                                    'Gross Profit', 'Operating Income','Interest Expense',
                                                    'EBITDA','Net Income',]]
income_statement_df_hist
# Out:
#                       2023-12-31      2022-12-31      2021-12-31  \
# Total Revenue     155498000000.0  142610000000.0  111239000000.0
# Cost Of Revenue   125809000000.0  118042000000.0   89253000000.0
# Gross Profit       29689000000.0   24568000000.0   21986000000.0
# Operating Income   18476000000.0   14209000000.0   13454000000.0
# Interest Expense     656000000.0     230000000.0     236000000.0
# EBITDA             26726000000.0   32305000000.0   22791000000.0
# Net Income         11290000000.0   17941000000.0   12382000000.0
#
#                      2020-12-31 2019-12-31
# Total Revenue     98990000000.0        NaN
# Cost Of Revenue   85408000000.0        NaN
# Gross Profit      13582000000.0        NaN
# Operating Income   4760000000.0        NaN
# Interest Expense    458000000.0        NaN
# EBITDA            11819000000.0        NaN
# Net Income         3775000000.0        NaN

# %%
for index, row in income_statement_df_hist.iterrows():
    plt.figure(figsize=(4, 3))  # Create a new figure for each row
    row.plot(kind= 'bar', color = 'c' )  # Plot a histogram (use 'bar' for row-wise data)
    plt.title(f'{index}')
    plt.xlabel('Columns')
    plt.ylabel('Values')
    plt.show()  # Display the histogram

# %%
transposed_income_statement_df_hist = income_statement_df_hist.T
transposed_income_statement_df_hist_percentage = transposed_income_statement_df_hist.div(transposed_income_statement_df_hist.sum(axis=1).replace(0, 1), axis=0) * 100
transposed_income_statement_df_hist_percentage
# Out:
#            Total Revenue Cost Of Revenue Gross Profit Operating Income  \
# 2023-12-31     42.238363       34.173856     8.064507         5.018688
# 2022-12-31     40.756777       33.735442     7.021334         4.060817
# 2021-12-31     40.996016       32.893297     8.102719         4.958337
# 2020-12-31     45.243885       39.036162     6.207722         2.175582
# 2019-12-31           NaN             NaN          NaN              NaN
#
#            Interest Expense    EBITDA Net Income
# 2023-12-31         0.178191  7.259659   3.066735
# 2022-12-31         0.065732  9.232506   5.127392
# 2021-12-31         0.086975  8.399394   4.563262
# 2020-12-31         0.209331  5.401934   1.725383
# 2019-12-31              NaN       NaN        NaN

# %%
transposed_income_statement_df_hist.plot(subplots= True, marker = 'o', figsize=(10,12), sharex= False, sharey=False)
plt.tight_layout()
plt.show()

# %%
income_statement_df_hist_percentage = income_statement_df_hist.pct_change(axis='columns', fill_method=None) * 100
income_statement_df_hist_percentage
# Out:
#                  2023-12-31 2022-12-31 2021-12-31 2020-12-31 2019-12-31
# Total Revenue           NaN  -8.288209 -21.997756 -11.011426        NaN
# Cost Of Revenue         NaN  -6.173644 -24.388777  -4.307978        NaN
# Gross Profit            NaN -17.248813 -10.509606 -38.224325        NaN
# Operating Income        NaN -23.094826  -5.313534 -64.620187        NaN
# Interest Expense        NaN -64.939024   2.608696  94.067797        NaN
# EBITDA                  NaN  20.874804 -29.450549  -48.14181        NaN
# Net Income              NaN   58.91054 -30.984895 -69.512195        NaN

# %%
# Plot each row
for idx, row in income_statement_df_hist_percentage.iterrows():
    row.plot(kind='bar', title=f"{idx} Percentage Differences Between Consecutive Values")
    plt.ylabel("Percentage Change (%)")
    plt.xlabel("Columns")
    plt.axhline(0, color='black', linewidth=0.5)  # Add a line at 0% for reference
    plt.show()

# %% [markdown]
# ### 6.1 Income Statement for the last year with Vertical Analysis

# %%
income_statement_df_last = pd.DataFrame(income_statement_df.iloc[:,0])
income_statement_df_last
# Out:
#                                                         2023-12-31
# Tax Effect Of Unusual Items                             -6336000.0
# Tax Rate For Calcs                                           0.288
# Normalized EBITDA                                    26748000000.0
# Total Unusual Items                                    -22000000.0
# Total Unusual Items Excluding Goodwill                 -22000000.0
# Net Income From Continuing Operation Net Minori...   11290000000.0
# Reconciled Depreciation                               8974000000.0
# Reconciled Cost Of Revenue                          125809000000.0
# EBITDA                                               26726000000.0
# EBIT                                                 17752000000.0
# Net Interest Income                                     45000000.0
# Interest Expense                                       656000000.0
# Interest Income                                        701000000.0
# ...

# %%
revenue = income_statement_df_last.loc['Operating Revenue'].values[0]
income_statement_df_last['Percentage from Operating Revenue'] = income_statement_df_last.iloc[:, [0]] / revenue * 100
income_statement_df_last
# Out:
#                                                    2023-12-31 00:00:00  \
# Tax Effect Of Unusual Items                                 -6336000.0
# Tax Rate For Calcs                                               0.288
# Normalized EBITDA                                        26748000000.0
# Total Unusual Items                                        -22000000.0
# Total Unusual Items Excluding Goodwill                     -22000000.0
# Net Income From Continuing Operation Net Minori...       11290000000.0
# Reconciled Depreciation                                   8974000000.0
# Reconciled Cost Of Revenue                              125809000000.0
# EBITDA                                                   26726000000.0
# EBIT                                                     17752000000.0
# Net Interest Income                                         45000000.0
# Interest Expense                                           656000000.0
# ...

# %% [markdown]
# ### 6.2 Income Statement for the previous year with Vertical Analysis

# %%
income_statement_df_prev = pd.DataFrame(income_statement_df.iloc[:,1])
income_statement_df_prev
# Out:
#                                                         2022-12-31
# Tax Effect Of Unusual Items                            -47040000.0
# Tax Rate For Calcs                                            0.21
# Normalized EBITDA                                    32529000000.0
# Total Unusual Items                                   -224000000.0
# Total Unusual Items Excluding Goodwill                -224000000.0
# Net Income From Continuing Operation Net Minori...   17941000000.0
# Reconciled Depreciation                               8566000000.0
# Reconciled Cost Of Revenue                          118042000000.0
# EBITDA                                               32305000000.0
# EBIT                                                 23739000000.0
# Net Interest Income                                    673000000.0
# Interest Expense                                       230000000.0
# Interest Income                                        903000000.0
# ...

# %%
revenue = income_statement_df_prev.loc['Operating Revenue'].values[0]
income_statement_df_prev['Percentage from Operating Revenue'] = income_statement_df_prev.iloc[:, [0]] / revenue * 100
income_statement_df_prev
# Out:
#                                                    2022-12-31 00:00:00  \
# Tax Effect Of Unusual Items                                -47040000.0
# Tax Rate For Calcs                                                0.21
# Normalized EBITDA                                        32529000000.0
# Total Unusual Items                                       -224000000.0
# Total Unusual Items Excluding Goodwill                    -224000000.0
# Net Income From Continuing Operation Net Minori...       17941000000.0
# Reconciled Depreciation                                   8566000000.0
# Reconciled Cost Of Revenue                              118042000000.0
# EBITDA                                                   32305000000.0
# EBIT                                                     23739000000.0
# Net Interest Income                                        673000000.0
# Interest Expense                                           230000000.0
# ...

# %% [markdown]
# ### 6.3 Income Statement for the last two years with Vertical Analysis

# %%
df_concat_income = pd.concat([income_statement_df_last, income_statement_df_prev], axis=1)
df_concat_income
# Out:
#                                                    2023-12-31 00:00:00  \
# Tax Effect Of Unusual Items                                 -6336000.0
# Tax Rate For Calcs                                               0.288
# Normalized EBITDA                                        26748000000.0
# Total Unusual Items                                        -22000000.0
# Total Unusual Items Excluding Goodwill                     -22000000.0
# Net Income From Continuing Operation Net Minori...       11290000000.0
# Reconciled Depreciation                                   8974000000.0
# Reconciled Cost Of Revenue                              125809000000.0
# EBITDA                                                   26726000000.0
# EBIT                                                     17752000000.0
# Net Interest Income                                         45000000.0
# Interest Expense                                           656000000.0
# ...

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# ## 7. ROIC & WACC

# %% [markdown]
# __ROIC__

# %%
nopat = income_statement_df.loc["EBIT"] * (1 - income_statement_df.loc["Tax Provision"] / income_statement_df.loc["Pretax Income"])
nopat
# Out:
# 2023-12-31    12631789892.372484
# 2022-12-31     18763796758.68816
# 2021-12-31    12646142465.753426
# 2020-12-31     4195281501.340482
# 2019-12-31                   NaN
# dtype: object

# %%
invested_capital = balance_sheet_df.loc['Long Term Debt And Capital Lease Obligation'] + balance_sheet_df.loc['Stockholders Equity']
invested_capital
# Out:
# 2023-12-31    135220000000.0
# 2022-12-31    133339000000.0
# 2021-12-31    132035000000.0
# 2020-12-31    123348000000.0
# 2019-12-31               NaN
# dtype: object

# %%
ROIC = nopat / invested_capital
ROIC
# Out:
# 2023-12-31    0.093417
# 2022-12-31    0.140722
# 2021-12-31    0.095779
# 2020-12-31    0.034012
# 2019-12-31         NaN
# dtype: object

# %% [markdown]
# __WACC__

# %%
def calculate_wacc(E, D, Ke, Kd, tax_rate):
    equity_weight = E / (E + D)
    debt_weight = D / (E + D)
    wacc = (equity_weight * Ke) + (debt_weight * Kd) * (1 - tax_rate)
    return wacc

# %%
E = balance_sheet_df.loc['Stockholders Equity']
D = balance_sheet_df.loc['Long Term Debt']
Ke = 0.1
Kd = 0.06
tax_rate = 0.3

# %%
wacc_result = calculate_wacc(E, D, Ke, Kd, tax_rate)
wacc_result
# Out:
# 2023-12-31    0.081024
# 2022-12-31    0.080543
# 2021-12-31    0.075156
# 2020-12-31    0.071108
# 2019-12-31         NaN
# dtype: object

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# ## 8.Long-term Debt to Equity Ratio & ICR

# %% [markdown]
# __DE__

# %%
debt_equity_ratio = balance_sheet_df.loc['Long Term Debt'] / balance_sheet_df.loc['Stockholders Equity']  
debt_equity_ratio
# Out:
# 2023-12-31    0.486283
# 2022-12-31    0.504826
# 2021-12-31    0.749321
# 2020-12-31     0.99256
# 2019-12-31         NaN
# dtype: object

# %% [markdown]
# __ICR__

# %%
ICR = income_statement_df.loc['EBIT'] / income_statement_df.loc['Interest Expense']
ICR
# Out:
# 2023-12-31     27.060976
# 2022-12-31    103.213043
# 2021-12-31     69.050847
# 2020-12-31     12.401747
# 2019-12-31           NaN
# dtype: object

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# ## 9.Operating Cash to Total Debt

# %%
operating_cash = cash_flow.loc['Operating Cash Flow']
operating_cash
# Out:
# 2023-12-31    17542000000.0
# 2022-12-31    23523000000.0
# 2021-12-31    15914000000.0
# 2020-12-31    13251000000.0
# 2019-12-31              NaN
# Name: Operating Cash Flow, dtype: object

# %%
total_debt = balance_sheet_df.loc['Total Debt']
total_debt
# Out:
# 2023-12-31    71548000000.0
# 2022-12-31    71561000000.0
# 2021-12-31    83733000000.0
# 2020-12-31    87582000000.0
# 2019-12-31              NaN
# Name: Total Debt, dtype: object

# %%
operating_cash_To_total_debt = operating_cash / total_debt
operating_cash_To_total_debt
# Out:
# 2023-12-31    0.245178
# 2022-12-31    0.328713
# 2021-12-31    0.190056
# 2020-12-31    0.151298
# 2019-12-31         NaN
# dtype: object

# %% [markdown]
# __When Cash to Debt ratio close to 100% or 1, quick measure confirming that company has solid financials to pay off debt.__

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# ## 10.Operating Cash to Market capitalization

# %%
operating_cash_last = cash_flow.iloc[:,0].loc['Operating Cash Flow']
operating_cash_last
# Out:
# 17542000000.0

# %%
operating_cash_To_market_cap = operating_cash_last / market_cap
operating_cash_To_market_cap
# Out:
# 0.40022862526564923

# %%
dif_for_non_current_assets = market_cap - operating_cash_last
dif_for_non_current_assets
# Out:
# 26287948416.0

# %%
real_non_current_assets = balance_sheet_df.iloc[:,0].loc['Total Non Current Assets']
real_non_current_assets
# Out:
# 155918000000.0

# %% [markdown]
# __When Cash to Market Cap > 0.7 (>70%), market is valuing rest of balance sheet potentially at scrap prices / liquidation prices.__

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# ## 11.QuantStats: Portfolio analytics for quants

# %%
# %matplotlib inline
import quantstats as qs

# %% [markdown]
# __extend pandas functionality with metrics__

# %%
qs.extend_pandas()

# %% [markdown]
# __fetch the daily returns for a stock__

# %%
stock_ = qs.utils.download_returns(ticker)
stock_
# Out:
# Date
# 1996-11-08 00:00:00+01:00         NaN
# 1996-11-11 00:00:00+01:00   -0.002696
# 1996-11-12 00:00:00+01:00    0.007560
# 1996-11-13 00:00:00+01:00   -0.001588
# 1996-11-14 00:00:00+01:00    0.003237
# 1996-11-15 00:00:00+01:00    0.008147
# 1996-11-18 00:00:00+01:00    0.001518
# 1996-11-19 00:00:00+01:00    0.004224
# 1996-11-20 00:00:00+01:00   -0.015800
# 1996-11-21 00:00:00+01:00    0.000987
# 1996-11-22 00:00:00+01:00    0.007882
# 1996-11-25 00:00:00+01:00    0.031174
# 1996-11-26 00:00:00+01:00    0.016116
# 1996-11-27 00:00:00+01:00   -0.008760
# 1996-11-28 00:00:00+01:00    0.028394
# 1996-11-29 00:00:00+01:00    0.001271
# 1996-12-02 00:00:00+01:00    0.015235
# 1996-12-03 00:00:00+01:00    0.058323
# 1996-12-04 00:00:00+01:00   -0.006144
# 1996-12-05 00:00:00+01:00   -0.018071
# 1996-12-06 00:00:00+01:00   -0.018065
# 1996-12-09 00:00:00+01:00    0.032010
# 1996-12-10 00:00:00+01:00    0.006547
# 1996-12-11 00:00:00+01:00   -0.028631
# ...

# %% [markdown]
# __show sharpe ratio__

# %%
qs.stats.sharpe(stock_)
# Out:
# 0.392102840583451

# %% [markdown]
# __or using extend_pandas()__

# %%
stock_.sharpe()
# Out:
# 0.392102840583451

# %% [markdown]
# __Visualize stock performance__

# %%
qs.plots.snapshot(stock_, title='Stock Performance', show=True)
