# %%
import yfinance as yahooFinance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
pd.set_option('display.max_rows', None)

# %%
ticker = "VOW3.DE"

# %% [markdown]
#  # 1. Stock Information

# %%
stock = yahooFinance.Ticker(ticker)

# %%
stock_info = stock.info
stock_info
# Out:
# {'address1': 'Berliner Ring 2',
#  'city': 'Wolfsburg',
#  'zip': '38440',
#  'country': 'Germany',
#  'phone': '49 5361 9 0',
#  'fax': '49 5361 9 28282',
#  'website': 'https://www.volkswagen-group.com',
#  'industry': 'Auto Manufacturers',
#  'industryKey': 'auto-manufacturers',
#  'industryDisp': 'Auto Manufacturers',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %%
market_cap = stock_info['marketCap']
market_cap
# Out:
# 44356165632

# %%
exchange = stock_info['exchange']
exchange
# Out:
# 'GER'

# %%
averageVolume = stock_info['averageVolume']
averageVolume
# Out:
# 918422

# %%
averageVolume10days = stock_info['averageVolume10days']
averageVolume10days
# Out:
# 942410

# %%
currentPrice = stock_info['currentPrice']
currentPrice
# Out:
# 89.04

# %%
fiftyDayAverage_stockPrice = stock_info['fiftyDayAverage']
fiftyDayAverage_stockPrice
# Out:
# 85.5716

# %%
twoHundredDayAverage_StockPrice = stock_info['twoHundredDayAverage']
twoHundredDayAverage_StockPrice
# Out:
# 101.1423

# %%
forwardPE = stock_info['forwardPE']
forwardPE
# Out:
# 3.5528514

# %%
trailingPE = stock_info['trailingPE']
trailingPE
# Out:
# 3.644699

# %%
priceToBook = stock_info['priceToBook']
priceToBook
# Out:
# 0.27324787

# %%
currentRatio = stock_info['currentRatio']
currentRatio
# Out:
# 1.15

# %%
forwardEps = stock_info['forwardEps']
forwardEps
# Out:
# 26.89

# %%
trailingEps = stock_info['trailingEps']
trailingEps
# Out:
# 24.43

# %%
try:
  earningsGrowth = stock_info['earningsGrowth']
  print(earningsGrowth)
except Exception:
  print("An exception occurred")
# Out:
# -0.688

# %%
beta = stock_info['beta']
beta
# Out:
# 1.217

# %%
recommendationKey = stock_info['recommendationKey']
recommendationKey
# Out:
# 'buy'

# %%
shareHolderRightsRisk = stock_info['shareHolderRightsRisk']
shareHolderRightsRisk
# Out:
# 10

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
#  # 2. Holders

# %%
try:
  print(stock.major_holders)
except Exception:
  print("An exception occurred")
# Out:
# An exception occurred

# %%
try:
  print(stock.institutional_holders)
except Exception:
  print("An exception occurred")
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
try:
  print(stock.mutualfund_holders)
except:
  print("An exception occurred")
# Out:
#   Date Reported                                             Holder  pctHeld  \
# 0    2023-10-31  Vanguard International Stock Index-Total Intl ...   0.0132
# 1    2023-12-31  Vanguard Tax Managed Fund-Vanguard Developed M...   0.0079
# 2    2024-01-31                         iShares Core MSCI EAFE ETF   0.0057
# 3    2023-12-31                  Price (T.Rowe) Equity Income Fund   0.0042
# 4    2024-01-31                              iShares MSCI Eafe ETF   0.0031
# 5    2024-01-31                  Fidelity International Index Fund   0.0028
# 6    2023-12-31    Price (T.Rowe) International Value Equity Trust   0.0026
# 7    2023-12-31  SEI Institutional Investment Tr-World Equity E...   0.0026
# 8    2024-01-31     Price (T.Rowe) International Value Equity Fund   0.0025
# 9    2024-01-31                        iShares MSCI Eafe Value ETF   0.0022
#
#     Shares      Value
# 0  2720876  271625051
# 1  1634464  182733075
# 2  1165750  139703480
# 3   870000   97266000
# ...

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# # 3. Actions - Dividends & Stock Splits

# %%
stock.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2000-05-24 00:00:00+02:00   0.825037           0.0
# 2001-06-08 00:00:00+02:00   1.252466           0.0
# 2002-04-17 00:00:00+02:00   1.351869           0.0
# 2003-04-25 00:00:00+02:00   1.351869           0.0
# 2004-02-18 00:00:00+01:00   0.401659           0.0
# 2004-04-23 00:00:00+02:00   1.103363           0.0
# 2005-02-16 00:00:00+01:00   0.594050           0.0
# 2005-04-22 00:00:00+02:00   1.103363           0.0
# 2006-02-15 00:00:00+01:00   0.297025           0.0
# 2006-05-04 00:00:00+02:00   1.202765           0.0
# 2007-04-20 00:00:00+02:00   1.302167           0.0
# 2008-04-25 00:00:00+02:00   1.848879           0.0
# 2009-04-24 00:00:00+02:00   1.978102           0.0
# 2010-04-23 00:00:00+02:00   1.660000           0.0
# 2011-05-04 00:00:00+02:00   2.260000           0.0
# 2012-04-20 00:00:00+02:00   3.060000           0.0
# 2013-04-26 00:00:00+02:00   3.560000           0.0
# ...

# %%
df_dividends = pd.DataFrame(stock.dividends)
df_new_dividends = df_dividends.groupby(['Date']).agg({'Dividends': 'sum'}).reset_index()
df_new_dividends
# Out:
#                         Date  Dividends
# 0  2000-05-24 00:00:00+02:00   0.825037
# 1  2001-06-08 00:00:00+02:00   1.252466
# 2  2002-04-17 00:00:00+02:00   1.351869
# 3  2003-04-25 00:00:00+02:00   1.351869
# 4  2004-02-18 00:00:00+01:00   0.401659
# 5  2004-04-23 00:00:00+02:00   1.103363
# 6  2005-02-16 00:00:00+01:00   0.594050
# 7  2005-04-22 00:00:00+02:00   1.103363
# 8  2006-02-15 00:00:00+01:00   0.297025
# 9  2006-05-04 00:00:00+02:00   1.202765
# 10 2007-04-20 00:00:00+02:00   1.302167
# 11 2008-04-25 00:00:00+02:00   1.848879
# 12 2009-04-24 00:00:00+02:00   1.978102
# 13 2010-04-23 00:00:00+02:00   1.660000
# 14 2011-05-04 00:00:00+02:00   2.260000
# 15 2012-04-20 00:00:00+02:00   3.060000
# 16 2013-04-26 00:00:00+02:00   3.560000
# 17 2014-05-14 00:00:00+02:00   4.060000
# 18 2015-05-06 00:00:00+02:00   4.860000
# 19 2016-06-23 00:00:00+02:00   0.170000
# 20 2017-05-11 00:00:00+02:00   2.060000
# 21 2018-05-04 00:00:00+02:00   3.960000
# ...

# %%
df_new_dividends['Date_in_Datetime'] = pd.to_datetime(df_new_dividends['Date'])
df_new_dividends['Year'] = df_new_dividends['Date_in_Datetime'].dt.year
df_new_dividends
# Out:
#                         Date  Dividends          Date_in_Datetime  Year
# 0  2000-05-24 00:00:00+02:00   0.825037 2000-05-24 00:00:00+02:00  2000
# 1  2001-06-08 00:00:00+02:00   1.252466 2001-06-08 00:00:00+02:00  2001
# 2  2002-04-17 00:00:00+02:00   1.351869 2002-04-17 00:00:00+02:00  2002
# 3  2003-04-25 00:00:00+02:00   1.351869 2003-04-25 00:00:00+02:00  2003
# 4  2004-02-18 00:00:00+01:00   0.401659 2004-02-18 00:00:00+01:00  2004
# 5  2004-04-23 00:00:00+02:00   1.103363 2004-04-23 00:00:00+02:00  2004
# 6  2005-02-16 00:00:00+01:00   0.594050 2005-02-16 00:00:00+01:00  2005
# 7  2005-04-22 00:00:00+02:00   1.103363 2005-04-22 00:00:00+02:00  2005
# 8  2006-02-15 00:00:00+01:00   0.297025 2006-02-15 00:00:00+01:00  2006
# 9  2006-05-04 00:00:00+02:00   1.202765 2006-05-04 00:00:00+02:00  2006
# 10 2007-04-20 00:00:00+02:00   1.302167 2007-04-20 00:00:00+02:00  2007
# 11 2008-04-25 00:00:00+02:00   1.848879 2008-04-25 00:00:00+02:00  2008
# ...

# %%
df_new_dividends_converted= df_new_dividends.groupby(['Year']).agg({'Dividends': 'sum'}).reset_index()
df_new_dividends_converted
# Out:
#     Year  Dividends
# 0   2000   0.825037
# 1   2001   1.252466
# 2   2002   1.351869
# 3   2003   1.351869
# 4   2004   1.505022
# 5   2005   1.697413
# 6   2006   1.499790
# 7   2007   1.302167
# 8   2008   1.848879
# 9   2009   1.978102
# 10  2010   1.660000
# 11  2011   2.260000
# 12  2012   3.060000
# 13  2013   3.560000
# 14  2014   4.060000
# 15  2015   4.860000
# 16  2016   0.170000
# 17  2017   2.060000
# 18  2018   3.960000
# 19  2019   4.860000
# 20  2020   4.860000
# 21  2021   4.860000
# 22  2022  26.620000
# 23  2023  17.520000
# 24  2024   9.060000

# %%
# Apply a style with more contrast
plt.style.use("ggplot")
plt.figure(figsize=(12, 8))

# Use a more contrasting color for the bars
plt.bar(df_new_dividends_converted['Year'], df_new_dividends_converted['Dividends'], color='lightgreen', edgecolor='black')

# Set x-axis ticks to display every year, and rotate them
plt.xticks(np.arange(df_new_dividends_converted['Year'].min(), df_new_dividends_converted['Year'].max() + 1, 1), rotation=45)

# Add labels and title
plt.xlabel('Year', fontsize=14)
plt.ylabel('Total Dividends', fontsize=14)
plt.title('Dividends by Year', fontsize=16)

# Improve grid visibility
plt.grid(True, which='both', linestyle='-', linewidth=0.5, alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Define the style and figure size
plt.style.use("ggplot")
plt.figure(figsize=(12, 8))

# Plot the data
plt.plot(df_new_dividends_converted['Year'], df_new_dividends_converted['Dividends'], marker = 'o', color='lightgreen')

# Set x-axis ticks to display every year between 1 and rotate them
plt.xticks(np.arange(df_new_dividends_converted['Year'].min(), df_new_dividends_converted['Year'].max() + 1, 1), rotation=45)

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Total Dividends')
plt.title('Dividends by Year')

# Show grid and plot
plt.grid(True)
plt.show()

# %%
dividend_Yield = stock_info['dividendYield']
dividend_Yield
# Out:
# 0.1022

# %%
trailingAnnualDividendYield = stock_info['trailingAnnualDividendYield']
trailingAnnualDividendYield
# Out:
# 0.10218813

# %%
try:
    avg_DvidendYield_5_years = stock_info['fiveYearAvgDividendYield']
    print(avg_DvidendYield_5_years)
except Exception:
    print("An exception occurred")
# Out:
# 2.31

# %%
payoutRatio = stock_info['payoutRatio']
payoutRatio
# Out:
# 0.3709

# %%
stock.splits
# Out:
# Series([], Name: Stock Splits, dtype: float64)

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# # 4. Balance Sheet Statement

# %%
balance_sheet_df = pd.DataFrame(stock.balance_sheet)
balance_sheet_df
# Out:
#                                                         2023-12-31  \
# Ordinary Shares Number                                 501295263.0
# Share Issued                                           501295263.0
# Net Debt                                            144030000000.0
# Total Debt                                          193972000000.0
# Tangible Book Value                                  86585000000.0
# Invested Capital                                    363173000000.0
# Working Capital                                      33770000000.0
# Net Tangible Assets                                  86585000000.0
# Capital Lease Obligations                             6493000000.0
# Common Stock Equity                                 175694000000.0
# Total Capitalization                                289398000000.0
# Total Equity Gross Minority Interest                189912000000.0
# Minority Interest                                    14218000000.0
# ...

# %%
balance_sheet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, Ordinary Shares Number to Cash Financial
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   2023-12-31 00:00:00  80 non-null     object
#  1   2022-12-31 00:00:00  80 non-null     object
#  2   2021-12-31 00:00:00  80 non-null     object
#  3   2020-12-31 00:00:00  81 non-null     object
# dtypes: object(4)
# memory usage: 3.2+ KB

# %% [markdown]
# ## 4.1 balance_df_liabilities

# %%
balance_df_liabilities = balance_sheet_df.loc[['Accounts Payable','Current Liabilities','Long Term Debt','Total Liabilities Net Minority Interest']]
balance_df_liabilities
# Out:
#                                              2023-12-31      2022-12-31  \
# Accounts Payable                          30901000000.0   28738000000.0
# Current Liabilities                      205874000000.0  182723000000.0
# Long Term Debt                           113704000000.0  113812000000.0
# Total Liabilities Net Minority Interest  410426000000.0  385685000000.0
#
#                                              2021-12-31      2020-12-31
# Accounts Payable                          23624000000.0   22675000000.0
# Current Liabilities                      164393000000.0  165410000000.0
# Long Term Debt                           123892000000.0  107279000000.0
# Total Liabilities Net Minority Interest  382455000000.0  368331000000.0

# %%
transposed_df_liabilities = balance_df_liabilities.T
transposed_df_liabilities
# Out:
#            Accounts Payable Current Liabilities  Long Term Debt  \
# 2023-12-31    30901000000.0      205874000000.0  113704000000.0
# 2022-12-31    28738000000.0      182723000000.0  113812000000.0
# 2021-12-31    23624000000.0      164393000000.0  123892000000.0
# 2020-12-31    22675000000.0      165410000000.0  107279000000.0
#
#            Total Liabilities Net Minority Interest
# 2023-12-31                          410426000000.0
# 2022-12-31                          385685000000.0
# 2021-12-31                          382455000000.0
# 2020-12-31                          368331000000.0

# %%
transposed_df_liabilities.plot(kind = 'line',marker='o',subplots= True, color = 'r',figsize=(10,12), sharex= False, sharey=False)
plt.tight_layout()
plt.show()

# %%
# Replace zero values with NaN to avoid division by zero
balance_df_liabilities_safe = transposed_df_liabilities.replace(0, pd.NA)

# Calculate percentage changes dynamically
balance_df_liabilities_percentage = balance_df_liabilities_safe.pct_change(axis=0, fill_method=None).mul(100)

# Display the result
balance_df_liabilities_percentage
# Out:
#            Accounts Payable Current Liabilities Long Term Debt  \
# 2023-12-31              NaN                 NaN            NaN
# 2022-12-31        -6.999773          -11.245228       0.094983
# 2021-12-31       -17.795254          -10.031578       8.856711
# 2020-12-31        -4.017101            0.618639      -13.40926
#
#            Total Liabilities Net Minority Interest
# 2023-12-31                                     NaN
# 2022-12-31                               -6.028127
# 2021-12-31                               -0.837471
# 2020-12-31                               -3.692983

# %%
values = balance_df_liabilities_safe
percentages = balance_df_liabilities_percentage

# Create subplots
fig, axes = plt.subplots(nrows=values.shape[1], ncols=1,figsize=(10, 12), sharex=False, sharey=False)

for idx, liability in enumerate(values.columns):
    ax = axes[idx]
    ax.plot(values.index, values[liability], marker='o', color = 'r', label=f"{liability} Values")
    
    # Add annotations for percentage changes
    for year, value in enumerate(values[liability]):
        if not pd.isna(value):
            percentage = percentages[liability].iloc[year]
            if not pd.isna(percentage):
                ax.text(
                    values.index[year], value, f"{percentage:.2f}%", fontsize=10,
                    ha='center', va='bottom', color='black'
                )
    
    # Set labels and title for each subplot
    ax.set_title(f"{liability} Over Time", fontsize=14)
    ax.set_ylabel("Values (in Billions)", fontsize=12)
    ax.grid(True)
    ax.legend()

# Set shared x-axis label
axes[-1].set_xlabel("Years", fontsize=12)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## 4.2 balance_df_assets

# %%
balance_df_assets = balance_sheet_df.loc[['Cash And Cash Equivalents','Net PPE','Goodwill And Other Intangible Assets', 'Total Assets']]
balance_df_assets
# Out:
#                                           2023-12-31      2022-12-31  \
# Cash And Cash Equivalents              43449000000.0   29172000000.0
# Net PPE                               130975000000.0  123271000000.0
# Goodwill And Other Intangible Assets   89109000000.0   83241000000.0
# Total Assets                          600338000000.0  564013000000.0
#
#                                           2021-12-31      2020-12-31
# Cash And Cash Equivalents              39724000000.0   33910000000.0
# Net PPE                               123394000000.0  114569000000.0
# Goodwill And Other Intangible Assets   77689000000.0   67968000000.0
# Total Assets                          528609000000.0  497114000000.0

# %%
transposed_df_assets = balance_df_assets.T
transposed_df_assets
# Out:
#            Cash And Cash Equivalents         Net PPE  \
# 2023-12-31             43449000000.0  130975000000.0
# 2022-12-31             29172000000.0  123271000000.0
# 2021-12-31             39724000000.0  123394000000.0
# 2020-12-31             33910000000.0  114569000000.0
#
#            Goodwill And Other Intangible Assets    Total Assets
# 2023-12-31                        89109000000.0  600338000000.0
# 2022-12-31                        83241000000.0  564013000000.0
# 2021-12-31                        77689000000.0  528609000000.0
# 2020-12-31                        67968000000.0  497114000000.0

# %%
transposed_df_assets.plot(kind = 'line',marker='o',subplots= True, color = 'b',figsize=(10,12), sharex= False, sharey=False)
plt.tight_layout()
plt.show()

# %%
# Replace zero values with NaN to avoid division by zero
balance_df_assets_safe = transposed_df_assets.replace(0, pd.NA)

# Calculate percentage changes dynamically
balance_df_assets_percentage = balance_df_assets_safe.pct_change(axis=0, fill_method=None).mul(100)

# Display the result
balance_df_assets_percentage
# Out:
#            Cash And Cash Equivalents   Net PPE  \
# 2023-12-31                       NaN       NaN
# 2022-12-31                -32.859214 -5.882039
# 2021-12-31                 36.171671   0.09978
# 2020-12-31                -14.635988 -7.151887
#
#            Goodwill And Other Intangible Assets Total Assets
# 2023-12-31                                  NaN          NaN
# 2022-12-31                            -6.585193    -6.050758
# 2021-12-31                             -6.66979     -6.27716
# 2020-12-31                           -12.512711     -5.95809

# %%
values = balance_df_assets_safe
percentages = balance_df_assets_percentage

# Create subplots
fig, axes = plt.subplots(nrows=values.shape[1], ncols=1,figsize=(10, 12), sharex=False, sharey=False)

for idx, asset in enumerate(values.columns):
    ax = axes[idx]
    ax.plot(values.index, values[asset], marker='o', color = 'b', label=f"{asset} Values")
    
    # Add annotations for percentage changes
    for year, value in enumerate(values[asset]):
        if not pd.isna(value):
            percentage = percentages[asset].iloc[year]
            if not pd.isna(percentage):
                ax.text(
                    values.index[year], value, f"{percentage:.2f}%", fontsize=10,
                    ha='center', va='bottom', color='black'
                )
    
    # Set labels and title for each subplot
    ax.set_title(f"{asset} Over Time", fontsize=14)
    ax.set_ylabel("Values (in Billions)", fontsize=12)
    ax.grid(True)
    ax.legend()

# Set shared x-axis label
axes[-1].set_xlabel("Years", fontsize=12)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## 4.3 Balance Sheet for the last year with Vertical Analysis

# %%
balance_sheet_df_last = pd.DataFrame(balance_sheet_df.iloc[:,0])
balance_sheet_df_last
# Out:
#                                                         2023-12-31
# Ordinary Shares Number                                 501295263.0
# Share Issued                                           501295263.0
# Net Debt                                            144030000000.0
# Total Debt                                          193972000000.0
# Tangible Book Value                                  86585000000.0
# Invested Capital                                    363173000000.0
# Working Capital                                      33770000000.0
# Net Tangible Assets                                  86585000000.0
# Capital Lease Obligations                             6493000000.0
# Common Stock Equity                                 175694000000.0
# Total Capitalization                                289398000000.0
# Total Equity Gross Minority Interest                189912000000.0
# Minority Interest                                    14218000000.0
# ...

# %%
total_assets = balance_sheet_df_last.loc['Total Assets'].values[0]
balance_sheet_df_last['Percentage from Total Assets/Liabilities'] = balance_sheet_df_last.iloc[:, [0]] / total_assets * 100
balance_sheet_df_last
# Out:
#                                                    2023-12-31 00:00:00  \
# Ordinary Shares Number                                     501295263.0
# Share Issued                                               501295263.0
# Net Debt                                                144030000000.0
# Total Debt                                              193972000000.0
# Tangible Book Value                                      86585000000.0
# Invested Capital                                        363173000000.0
# Working Capital                                          33770000000.0
# Net Tangible Assets                                      86585000000.0
# Capital Lease Obligations                                 6493000000.0
# Common Stock Equity                                     175694000000.0
# Total Capitalization                                    289398000000.0
# Total Equity Gross Minority Interest                    189912000000.0
# ...

# %% [markdown]
# ## 4.4 Balance Sheet for the previous year with Vertical Analysis

# %%
balance_sheet_df = pd.DataFrame(stock.balance_sheet)
balance_sheet_df_prev = pd.DataFrame(balance_sheet_df.iloc[:,1])
balance_sheet_df_prev
# Out:
#                                                         2022-12-31
# Ordinary Shares Number                                 501295263.0
# Share Issued                                           501295263.0
# Net Debt                                            142879000000.0
# Total Debt                                          178436000000.0
# Tangible Book Value                                  82135000000.0
# Invested Capital                                    337427000000.0
# Working Capital                                      41436000000.0
# Net Tangible Assets                                  82135000000.0
# Capital Lease Obligations                             6385000000.0
# Common Stock Equity                                 165376000000.0
# Total Capitalization                                279188000000.0
# Total Equity Gross Minority Interest                178328000000.0
# Minority Interest                                    12952000000.0
# ...

# %%
total_assets = balance_sheet_df_prev.loc['Total Assets'].values[0]
balance_sheet_df_prev['Percentage from Total Assets/Liabilities'] = balance_sheet_df_prev.iloc[:, [0]] / total_assets * 100
balance_sheet_df_prev
# Out:
#                                                    2022-12-31 00:00:00  \
# Ordinary Shares Number                                     501295263.0
# Share Issued                                               501295263.0
# Net Debt                                                142879000000.0
# Total Debt                                              178436000000.0
# Tangible Book Value                                      82135000000.0
# Invested Capital                                        337427000000.0
# Working Capital                                          41436000000.0
# Net Tangible Assets                                      82135000000.0
# Capital Lease Obligations                                 6385000000.0
# Common Stock Equity                                     165376000000.0
# Total Capitalization                                    279188000000.0
# Total Equity Gross Minority Interest                    178328000000.0
# ...

# %% [markdown]
# ## 4.5 Balance Sheet for the last two years with Vertical Analysis

# %%
df_concat_balance = pd.concat([balance_sheet_df_last, balance_sheet_df_prev], axis=1)
df_concat_balance
# Out:
#                                                    2023-12-31 00:00:00  \
# Ordinary Shares Number                                     501295263.0
# Share Issued                                               501295263.0
# Net Debt                                                144030000000.0
# Total Debt                                              193972000000.0
# Tangible Book Value                                      86585000000.0
# Invested Capital                                        363173000000.0
# Working Capital                                          33770000000.0
# Net Tangible Assets                                      86585000000.0
# Capital Lease Obligations                                 6493000000.0
# Common Stock Equity                                     175694000000.0
# Total Capitalization                                    289398000000.0
# Total Equity Gross Minority Interest                    189912000000.0
# ...

# %%
try:
  retained_earnings = df_concat_balance.loc['Retained Earnings']
  print(retained_earnings)
except Exception:
  print("An exception occurred")
# Out:
# 2023-12-31 00:00:00                         147830000000.0
# Percentage from Total Assets/Liabilities         24.624462
# 2022-12-31 00:00:00                         137272000000.0
# Percentage from Total Assets/Liabilities         24.338446
# Name: Retained Earnings, dtype: object

# %%
df_concat_balance.loc['Total Capitalization']
# Out:
# 2023-12-31 00:00:00                         289398000000.0
# Percentage from Total Assets/Liabilities         48.205844
# 2022-12-31 00:00:00                         279188000000.0
# Percentage from Total Assets/Liabilities         49.500277
# Name: Total Capitalization, dtype: object

# %%
df_concat_balance.loc['Net PPE']
# Out:
# 2023-12-31 00:00:00                         130975000000.0
# Percentage from Total Assets/Liabilities         21.816876
# 2022-12-31 00:00:00                         123271000000.0
# Percentage from Total Assets/Liabilities         21.856057
# Name: Net PPE, dtype: object

# %%
df_concat_balance.loc['Long Term Debt And Capital Lease Obligation']
# Out:
# 2023-12-31 00:00:00                         119085000000.0
# Percentage from Total Assets/Liabilities         19.836326
# 2022-12-31 00:00:00                         119095000000.0
# Percentage from Total Assets/Liabilities         21.115648
# Name: Long Term Debt And Capital Lease Obligation, dtype: object

# %%
df_concat_balance.loc['Goodwill']
# Out:
# 2023-12-31 00:00:00                         26292000000.0
# Percentage from Total Assets/Liabilities         4.379533
# 2022-12-31 00:00:00                         26202000000.0
# Percentage from Total Assets/Liabilities         4.645638
# Name: Goodwill, dtype: object

# %%
df_concat_balance.loc['Cash And Cash Equivalents']
# Out:
# 2023-12-31 00:00:00                         43449000000.0
# Percentage from Total Assets/Liabilities         7.237423
# 2022-12-31 00:00:00                         29172000000.0
# Percentage from Total Assets/Liabilities         5.172221
# Name: Cash And Cash Equivalents, dtype: object

# %%
df_concat_balance.loc['Taxes Receivable']
# Out:
# 2023-12-31 00:00:00                         7080000000.0
# Percentage from Total Assets/Liabilities        1.179336
# 2022-12-31 00:00:00                         6584000000.0
# Percentage from Total Assets/Liabilities        1.167349
# Name: Taxes Receivable, dtype: object

# %%
df_concat_balance.loc['Accounts Receivable']
# Out:
# 2023-12-31 00:00:00                         67203000000.0
# Percentage from Total Assets/Liabilities        11.194194
# 2022-12-31 00:00:00                         60202000000.0
# Percentage from Total Assets/Liabilities        10.673867
# Name: Accounts Receivable, dtype: object

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# # 5. Cash Flow Statement

# %%
cash_flow = stock.cash_flow
cash_flow
# Out:
#                                                 2023-12-31     2022-12-31  \
# Free Cash Flow                               -6439000000.0   5825000000.0
# Repayment Of Debt                           -32582000000.0 -25638000000.0
# Issuance Of Debt                             37740000000.0  23876000000.0
# Capital Expenditure                         -25795000000.0 -22671000000.0
# End Cash Position                            43522000000.0  29738000000.0
# Other Cash Adjustment Outside Changein Cash     -2000000.0            NaN
# Beginning Cash Position                      29738000000.0  39123000000.0
# Effect Of Exchange Rate Changes              -1764000000.0   -285000000.0
# Changes In Cash                              15550000000.0  -9100000000.0
# Other Cash Adjustment Inside Changein Cash      -2000000.0      1000000.0
# Financing Cash Flow                          16008000000.0   4225000000.0
# Net Other Financing Charges                  22769000000.0  11832000000.0
# ...

# %%
try:
  print(cash_flow.loc['Long Term Debt Payments'])
except:
    print("An exception occurred")
# Out:
# 2023-12-31   -32582000000.0
# 2022-12-31   -25638000000.0
# 2021-12-31   -30557000000.0
# 2020-12-31   -19815000000.0
# Name: Long Term Debt Payments, dtype: object

# %% [markdown]
# ## 5.1 cash_flow_df

# %%
cash_flow_df = cash_flow.loc[['Operating Cash Flow','Investing Cash Flow', 'Financing Cash Flow']]
cash_flow_df
# Out:
#                         2023-12-31     2022-12-31     2021-12-31  \
# Operating Cash Flow  19356000000.0  28496000000.0  38633000000.0
# Investing Cash Flow -19812000000.0 -41822000000.0 -26128000000.0
# Financing Cash Flow  16008000000.0   4225000000.0  -7754000000.0
#
#                         2020-12-31
# Operating Cash Flow  24901000000.0
# Investing Cash Flow -22690000000.0
# Financing Cash Flow   7637000000.0

# %%
transposed_cash_flow_df = cash_flow_df.T

# Plot each column as a bar plot in subplots
transposed_cash_flow_df.plot(
    kind='bar',
    subplots=True,
    figsize=(10, 12),
    sharex=False,
    sharey=False,
    legend=False,  # Hide legends since column names are the titles
    color='skyblue',
    edgecolor='black',
)

# Add titles and layout adjustments
for i, ax in enumerate(plt.gcf().axes):
    ax.set_title(transposed_cash_flow_df.columns[i])  # Set column names as titles
    ax.set_xlabel("Year")
    ax.set_ylabel("Value")
    for bar in ax.patches:
        height = bar.get_height()
        if not pd.isna(height):  # Annotate bar values
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                height,
                f"{height:,.0f}",
                ha="center",
                va="bottom",
                fontsize=8,
                rotation=90,
            )

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5.2 cash_flow_df_percentage

# %%
transposed_cash_flow_df = cash_flow_df.T
transposed_cash_flow_df
# Out:
#            Operating Cash Flow Investing Cash Flow Financing Cash Flow
# 2023-12-31       19356000000.0      -19812000000.0       16008000000.0
# 2022-12-31       28496000000.0      -41822000000.0        4225000000.0
# 2021-12-31       38633000000.0      -26128000000.0       -7754000000.0
# 2020-12-31       24901000000.0      -22690000000.0        7637000000.0

# %%
# Replace zero values with NaN to avoid division by zero
cash_flow_df_safe = transposed_cash_flow_df.replace(0, pd.NA)

# Calculate percentage changes dynamically
cash_flow_df_percentage = cash_flow_df_safe.pct_change(axis=0, fill_method=None).mul(100)

# Display the result
cash_flow_df_percentage
# Out:
#            Operating Cash Flow Investing Cash Flow Financing Cash Flow
# 2023-12-31                 NaN                 NaN                 NaN
# 2022-12-31             47.2205          111.094286          -73.606947
# 2021-12-31           35.573414          -37.525704         -283.526627
# 2020-12-31          -35.544742          -13.158298         -198.491101

# %%
# Iterate through rows and create a bar plot with annotations
for index, row in cash_flow_df.iterrows():
    percentages = cash_flow_df_percentage[index]
    
    # Create a bar plot
    plt.figure(figsize= (8, 6))
    bars = row.plot(kind='bar', color='skyblue', edgecolor='black')
    
    # Annotate percentage differences above each bar
    for x, y in enumerate(row.values):
        if x > 0:  # Skip the first value since there is no previous value for comparison
            percentage = percentages.iloc[x]
            if not pd.isna(percentage):
                plt.text(
                    x, y, f"{percentage:.2f}%",
                    ha='center', va='bottom', fontsize=9, color='black'
                )
    
    # Add labels and title
    plt.title(f'{index}')
    plt.xlabel('Year')
    plt.ylabel('Value')
    plt.show()

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# # 6. Income Statement

# %%
income_statement_df = pd.DataFrame(stock.income_stmt)
income_statement_df
# Out:
#                                                         2023-12-31  \
# Tax Effect Of Unusual Items                           -640594000.0
# Tax Rate For Calcs                                           0.227
# Normalized EBITDA                                    57172000000.0
# Total Unusual Items                                  -2822000000.0
# Total Unusual Items Excluding Goodwill               -2822000000.0
# Net Income From Continuing Operation Net Minori...   16599000000.0
# Reconciled Depreciation                              27566000000.0
# Reconciled Cost Of Revenue                          261262000000.0
# EBITDA                                               54350000000.0
# EBIT                                                 26784000000.0
# Net Interest Income                                  -1806000000.0
# Interest Expense                                      3590000000.0
# Interest Income                                       2656000000.0
# ...

# %% [markdown]
# ## 6.1 income_statement_df_hist

# %%
income_statement_df_hist = income_statement_df.loc[['Total Revenue','Total Expenses','Net Income Common Stockholders',
                                                'Diluted EPS']]
income_statement_df_hist
# Out:
#                                     2023-12-31      2022-12-31  \
# Total Revenue                   322284000000.0  279050000000.0
# Total Expenses                  296600000000.0  260842000000.0
# Net Income Common Stockholders   16013000000.0   14881000000.0
# Diluted EPS                              31.92           29.66
#
#                                     2021-12-31      2020-12-31
# Total Revenue                   250199000000.0  222885000000.0
# Total Expenses                  234247000000.0  212827000000.0
# Net Income Common Stockholders   14843000000.0    8334000000.0
# Diluted EPS                              29.59            16.6

# %%
transposed_income_statement_df_hist = income_statement_df_hist.T
transposed_income_statement_df_hist
# Out:
#              Total Revenue  Total Expenses Net Income Common Stockholders  \
# 2023-12-31  322284000000.0  296600000000.0                  16013000000.0
# 2022-12-31  279050000000.0  260842000000.0                  14881000000.0
# 2021-12-31  250199000000.0  234247000000.0                  14843000000.0
# 2020-12-31  222885000000.0  212827000000.0                   8334000000.0
#
#            Diluted EPS
# 2023-12-31       31.92
# 2022-12-31       29.66
# 2021-12-31       29.59
# 2020-12-31        16.6

# %%
transposed_income_statement_df_hist.plot(subplots= True, figsize=(10,12), sharex= False, sharey=False)
plt.show()

# %%
# Replace zero values with NaN to avoid division by zero
income_statement_df_hist_safe = transposed_income_statement_df_hist.replace(0, pd.NA)

# Calculate percentage changes dynamically
income_statement_df_hist_percentage= income_statement_df_hist_safe.pct_change(axis=0, fill_method=None).mul(100)

# Display the result
income_statement_df_hist_percentage
# Out:
#            Total Revenue Total Expenses Net Income Common Stockholders  \
# 2023-12-31           NaN            NaN                            NaN
# 2022-12-31    -13.414876     -12.055968                      -7.069256
# 2021-12-31    -10.339007     -10.195827                      -0.255359
# 2020-12-31     -10.91691      -9.144194                     -43.852321
#
#            Diluted EPS
# 2023-12-31         NaN
# 2022-12-31   -7.080201
# 2021-12-31   -0.236008
# 2020-12-31  -43.899966

# %%
values = income_statement_df_hist_safe
percentages = income_statement_df_hist_percentage

# Define a list of colors
colors = ['lightblue', 'red', 'pink', 'purple', ]

# Create subplots
fig, axes = plt.subplots(nrows=values.shape[1], ncols=1, figsize=(10, 12), sharex=False, sharey=False)

for idx, number in enumerate(values.columns):
    ax = axes[idx]
    
    # Assign a unique color for each plot
    color = colors[idx % len(colors)]  # This ensures it cycles through colors if there are more plots than colors
    
    # Plot values with the assigned color
    ax.plot(values.index, values[number], marker='o', color=color, label=f"{number} Values")
    
    # Add annotations for percentage changes
    for year, value in enumerate(values[number]):
        if not pd.isna(value):
            percentage = percentages[number].iloc[year]
            if not pd.isna(percentage):
                ax.text(
                    values.index[year], value, f"{percentage:.2f}%", fontsize=10,
                    ha='center', va='bottom', color='black'
                )
    
    # Set labels and title for each subplot
    ax.set_title(f"{number} Over Time", fontsize=14)
    ax.set_ylabel("Values (in Billions)", fontsize=12)
    ax.grid(True)
    ax.legend()

# Set shared x-axis label
axes[-1].set_xlabel("Years", fontsize=12)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## 6.2 Income Statement for the last year with Vertical Analysis

# %%
income_statement_df_last = pd.DataFrame(income_statement_df.iloc[:,0])
income_statement_df_last
# Out:
#                                                         2023-12-31
# Tax Effect Of Unusual Items                           -640594000.0
# Tax Rate For Calcs                                           0.227
# Normalized EBITDA                                    57172000000.0
# Total Unusual Items                                  -2822000000.0
# Total Unusual Items Excluding Goodwill               -2822000000.0
# Net Income From Continuing Operation Net Minori...   16599000000.0
# Reconciled Depreciation                              27566000000.0
# Reconciled Cost Of Revenue                          261262000000.0
# EBITDA                                               54350000000.0
# EBIT                                                 26784000000.0
# Net Interest Income                                  -1806000000.0
# Interest Expense                                      3590000000.0
# Interest Income                                       2656000000.0
# ...

# %%
revenue = income_statement_df_last.loc['Operating Revenue'].values[0]
income_statement_df_last['Percentage from Operating Revenue'] = income_statement_df_last.iloc[:, [0]] / revenue * 100
income_statement_df_last
# Out:
#                                                    2023-12-31 00:00:00  \
# Tax Effect Of Unusual Items                               -640594000.0
# Tax Rate For Calcs                                               0.227
# Normalized EBITDA                                        57172000000.0
# Total Unusual Items                                      -2822000000.0
# Total Unusual Items Excluding Goodwill                   -2822000000.0
# Net Income From Continuing Operation Net Minori...       16599000000.0
# Reconciled Depreciation                                  27566000000.0
# Reconciled Cost Of Revenue                              261262000000.0
# EBITDA                                                   54350000000.0
# EBIT                                                     26784000000.0
# Net Interest Income                                      -1806000000.0
# Interest Expense                                          3590000000.0
# ...

# %% [markdown]
# ## 6.3 Income Statement for the previous year with Vertical Analysis

# %%
income_statement_df_prev = pd.DataFrame(income_statement_df.iloc[:,1])
income_statement_df_prev
# Out:
#                                                         2022-12-31
# Tax Effect Of Unusual Items                            702744000.0
# Tax Rate For Calcs                                           0.282
# Normalized EBITDA                                    49708000000.0
# Total Unusual Items                                   2492000000.0
# Total Unusual Items Excluding Goodwill                2492000000.0
# Net Income From Continuing Operation Net Minori...   15457000000.0
# Reconciled Depreciation                              28485000000.0
# Reconciled Cost Of Revenue                          226866000000.0
# EBITDA                                               52200000000.0
# EBIT                                                 23715000000.0
# Net Interest Income                                  -1351000000.0
# Interest Expense                                      1645000000.0
# Interest Income                                       2561000000.0
# ...

# %%
revenue = income_statement_df_prev.loc['Operating Revenue'].values[0]
income_statement_df_prev['Percentage from Operating Revenue'] = income_statement_df_prev.iloc[:, [0]] / revenue * 100
income_statement_df_prev
# Out:
#                                                    2022-12-31 00:00:00  \
# Tax Effect Of Unusual Items                                702744000.0
# Tax Rate For Calcs                                               0.282
# Normalized EBITDA                                        49708000000.0
# Total Unusual Items                                       2492000000.0
# Total Unusual Items Excluding Goodwill                    2492000000.0
# Net Income From Continuing Operation Net Minori...       15457000000.0
# Reconciled Depreciation                                  28485000000.0
# Reconciled Cost Of Revenue                              226866000000.0
# EBITDA                                                   52200000000.0
# EBIT                                                     23715000000.0
# Net Interest Income                                      -1351000000.0
# Interest Expense                                          1645000000.0
# ...

# %% [markdown]
# ## 6.4 Income Statement for the last two years with Vertical Analysis

# %%
df_concat_income = pd.concat([income_statement_df_last, income_statement_df_prev], axis=1)
df_concat_income
# Out:
#                                                    2023-12-31 00:00:00  \
# Tax Effect Of Unusual Items                               -640594000.0
# Tax Rate For Calcs                                               0.227
# Normalized EBITDA                                        57172000000.0
# Total Unusual Items                                      -2822000000.0
# Total Unusual Items Excluding Goodwill                   -2822000000.0
# Net Income From Continuing Operation Net Minori...       16599000000.0
# Reconciled Depreciation                                  27566000000.0
# Reconciled Cost Of Revenue                              261262000000.0
# EBITDA                                                   54350000000.0
# EBIT                                                     26784000000.0
# Net Interest Income                                      -1806000000.0
# Interest Expense                                          3590000000.0
# ...

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# ## 7. ROIC & WACC

# %% [markdown]
# __ROIC__

# %%
nopat = income_statement_df.loc["EBIT"].replace({0: None}) * (1 - income_statement_df.loc["Tax Provision"] / income_statement_df.loc["Pretax Income"].replace({0: None}))
nopat
# Out:
# 2023-12-31    20702921100.284557
# 2022-12-31     17034612369.73267
# 2021-12-31    16938910662.824207
# 2020-12-31    10539336590.383131
# dtype: object

# %%
invested_capital = balance_sheet_df.loc['Long Term Debt And Capital Lease Obligation'].replace({0: None}) + balance_sheet_df.loc['Stockholders Equity'].replace({0: None})
invested_capital
# Out:
# 2023-12-31    294779000000.0
# 2022-12-31    284471000000.0
# 2021-12-31    273478000000.0
# 2020-12-31    239447000000.0
# dtype: object

# %%
ROIC = nopat / invested_capital
ROIC
# Out:
# 2023-12-31    0.070232
# 2022-12-31    0.059882
# 2021-12-31    0.061939
# 2020-12-31    0.044015
# dtype: object

# %% [markdown]
# __WACC__

# %%
def calculate_wacc(E, D, Ke, Kd, tax_rate):
    equity_weight = E / (E + D)
    debt_weight = D / (E + D)
    wacc = (equity_weight * Ke) + (debt_weight * Kd) * (1 - tax_rate)
    return wacc

# %%
E = balance_sheet_df.loc['Stockholders Equity'].replace({0: None})
D = balance_sheet_df.loc['Long Term Debt'].replace({0: None})
Ke = 0.1
Kd = 0.06
tax_rate = 0.3

# %%
wacc_result = calculate_wacc(E, D, Ke, Kd, tax_rate)
wacc_result
# Out:
# 2023-12-31    0.077212
# 2022-12-31    0.076356
# 2021-12-31    0.073222
# 2020-12-31    0.073447
# dtype: object

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# # 8. Retained Earnings vs Shareholders' Equity, Total Liabilities, Long Term Debt and Net Income

# %% [markdown]
# _1) Retained Earnings are a component of shareholders' equity. Comparing the two shows how much of the equity comes from retained earnings versus other sources like common stock or additional paid-in capital. <br> 2) Understanding how Retained Earnings grow relative to liabilities helps analyze the company's risk and leverage. A healthy company might show increasing retained earnings alongside controlled liability growth. <br> 3) Retained Earnings are directly linked to net income. Showing the two together illustrates how much of the profit is retained versus paid out or otherwise allocated._

# %%
data = {}

# %%
try:
  retained_earnings = balance_sheet_df.loc['Retained Earnings']
  print(retained_earnings)
  data["Retained Earnings"] = retained_earnings
except Exception:
  print("An exception occurred")
# Out:
# 2023-12-31    147830000000.0
# 2022-12-31    137272000000.0
# 2021-12-31    117342000000.0
# 2020-12-31    100772000000.0
# Name: Retained Earnings, dtype: object

# %%
try:
  equity = balance_sheet_df.loc['Stockholders Equity']
  data["Stockholders Equity"] = equity
  print(equity)
except Exception:
  print("An exception occurred")
# Out:
# 2023-12-31    175694000000.0
# 2022-12-31    165376000000.0
# 2021-12-31    144449000000.0
# 2020-12-31    127049000000.0
# Name: Stockholders Equity, dtype: object

# %%
 try:
  long_term_debt = balance_sheet_df.loc['Long Term Debt']
  data["Long Term Debt"] = long_term_debt
  print(long_term_debt)
except Exception:
  print("An exception occurred")
# Out:
# 2023-12-31    113704000000.0
# 2022-12-31    113812000000.0
# 2021-12-31    123892000000.0
# 2020-12-31    107279000000.0
# Name: Long Term Debt, dtype: object

# %%
try:
  total_liabilities = balance_sheet_df.loc['Total Liabilities Net Minority Interest']
  data["Total Liabilities"] = total_liabilities
  print(total_liabilities)
except Exception:
  print("An exception occurred")
# Out:
# 2023-12-31    410426000000.0
# 2022-12-31    385685000000.0
# 2021-12-31    382455000000.0
# 2020-12-31    368331000000.0
# Name: Total Liabilities Net Minority Interest, dtype: object

# %%
try:
  net_income = income_statement_df.loc['Net Income Common Stockholders']
  data["Net Income"] = net_income
  print(net_income)
except Exception:
  print("An exception occurred")
# Out:
# 2023-12-31    16013000000.0
# 2022-12-31    14881000000.0
# 2021-12-31    14843000000.0
# 2020-12-31     8334000000.0
# Name: Net Income Common Stockholders, dtype: object

# %%
if data:
    df_RE = pd.DataFrame(data)
    print(df_RE)
else:
    print("No data available to plot.")
# Out:
#            Retained Earnings Stockholders Equity  Long Term Debt  \
# 2023-12-31    147830000000.0      175694000000.0  113704000000.0
# 2022-12-31    137272000000.0      165376000000.0  113812000000.0
# 2021-12-31    117342000000.0      144449000000.0  123892000000.0
# 2020-12-31    100772000000.0      127049000000.0  107279000000.0
#
#            Total Liabilities     Net Income
# 2023-12-31    410426000000.0  16013000000.0
# 2022-12-31    385685000000.0  14881000000.0
# 2021-12-31    382455000000.0  14843000000.0
# 2020-12-31    368331000000.0   8334000000.0

# %%
if data:
    colors = ['blue', 'grey', 'orange','red', 'pink']
    df_RE.plot(kind='line', marker='o', subplots=True, figsize=(10, 12), sharex=False, sharey=False, color=colors)
    plt.tight_layout()
    plt.show()
else:
    print("No data available to plot.")

# %%
if data:
    # Replace zero values with NaN to avoid division by zero
    df_RE_safe = df_RE.replace(0, pd.NA)

   # Calculate percentage changes dynamically
    df_RE_percentage = df_RE_safe.pct_change(axis=0, fill_method=None).mul(100)

   # Display the result
    print(df_RE_percentage)
else:
    print("No data available to plot.")
# Out:
#            Retained Earnings Stockholders Equity Long Term Debt  \
# 2023-12-31               NaN                 NaN            NaN
# 2022-12-31         -7.141987           -5.872711       0.094983
# 2021-12-31         -14.51862          -12.654194       8.856711
# 2020-12-31        -14.121116          -12.045774      -13.40926
#
#            Total Liabilities Net Income
# 2023-12-31               NaN        NaN
# 2022-12-31         -6.028127  -7.069256
# 2021-12-31         -0.837471  -0.255359
# 2020-12-31         -3.692983 -43.852321

# %%
if data:      
    values = df_RE_safe
    percentages = df_RE_percentage

    # Define a list of colors
    colors = ['blue', 'grey', 'orange','red', 'pink']

    # Create subplots
    fig, axes = plt.subplots(nrows=values.shape[1], ncols=1, figsize=(10, 12), sharex=False, sharey=False)

    for idx, number in enumerate(values.columns):
        ax = axes[idx]

        # Assign a unique color for each plot
        color = colors[idx % len(colors)]  # This ensures it cycles through colors if there are more plots than colors

        # Plot values with the assigned color
        ax.plot(values.index, values[number], marker='o', color=color, label=f"{number} Values")

        # Add annotations for percentage changes
        for year, value in enumerate(values[number]):
            if not pd.isna(value):
                percentage = percentages[number].iloc[year]
                if not pd.isna(percentage):
                    ax.text(
                        values.index[year], value, f"{percentage:.2f}%", fontsize=10,
                        ha='center', va='bottom', color='black'
                    )

        # Set labels and title for each subplot
        ax.set_title(f"{number} Over Time", fontsize=14)
        ax.set_ylabel("Values (in Billions)", fontsize=12)
        ax.grid(True)
        ax.legend()

    # Set shared x-axis label
    axes[-1].set_xlabel("Years", fontsize=12)
    plt.tight_layout()

    # Show the plot
    plt.show()
else:
    print("No data available to plot.")

# %% [markdown]
# ## 9. Long-term Debt to Equity Ratio & ICR

# %% [markdown]
# __DE__

# %%
debt_equity_ratio = balance_sheet_df.loc['Long Term Debt'].replace({0: None}) / balance_sheet_df.loc['Stockholders Equity'].replace({0: None})  
debt_equity_ratio
# Out:
# 2023-12-31    0.647171
# 2022-12-31    0.688201
# 2021-12-31    0.857687
# 2020-12-31    0.844391
# dtype: object

# %% [markdown]
# __ICR__

# %%
ICR = income_statement_df.loc['EBIT'].replace({0: None}) / income_statement_df.loc['Interest Expense'].replace({0: None})
ICR
# Out:
# 2023-12-31     7.460724
# 2022-12-31    14.416413
# 2021-12-31     11.21106
# 2020-12-31      6.14418
# dtype: object

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# ## 10. Operating Cash to Total Debt

# %%
operating_cash = cash_flow.loc['Operating Cash Flow'].replace({0: None})
operating_cash
# Out:
# 2023-12-31    19356000000.0
# 2022-12-31    28496000000.0
# 2021-12-31    38633000000.0
# 2020-12-31    24901000000.0
# Name: Operating Cash Flow, dtype: object

# %%
total_debt = balance_sheet_df.loc['Total Debt'].replace({0: None})
total_debt
# Out:
# 2023-12-31    193972000000.0
# 2022-12-31    178436000000.0
# 2021-12-31    183370000000.0
# 2020-12-31    174312000000.0
# Name: Total Debt, dtype: object

# %%
operating_cash_To_total_debt = operating_cash / total_debt
operating_cash_To_total_debt
# Out:
# 2023-12-31    0.099788
# 2022-12-31    0.159699
# 2021-12-31    0.210683
# 2020-12-31    0.142853
# dtype: object

# %% [markdown]
# __When Cash to Debt ratio close to 100% or 1, quick measure confirming that company has solid financials to pay off debt.__

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# ## 11. Operating Cash to Market capitalization

# %%
operating_cash_last = cash_flow.iloc[:,0].loc['Operating Cash Flow']
operating_cash_last
# Out:
# 19356000000.0

# %%
operating_cash_To_market_cap = operating_cash_last / market_cap
operating_cash_To_market_cap
# Out:
# 0.4363767635053636

# %%
dif_for_non_current_assets = market_cap - operating_cash_last
dif_for_non_current_assets
# Out:
# 25000165632.0

# %%
real_non_current_assets = balance_sheet_df.iloc[:,0].loc['Total Non Current Assets']
real_non_current_assets
# Out:
# 360694000000.0

# %% [markdown]
# __When Cash to Market Cap > 0.7 (>70%), market is valuing rest of balance sheet potentially at scrap prices / liquidation prices.__

# %% [markdown]
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>
# <font color='red'>----------------------------------------------------------------------------------------------------------------------------------------------------</font>

# %% [markdown]
# ## 12. QuantStats: Portfolio analytics for quants

# %%
# %matplotlib inline
import quantstats as qs

# %% [markdown]
# __extend pandas functionality with metrics__

# %%
qs.extend_pandas()

# %% [markdown]
# __fetch the daily returns for a stock__

# %%
stock_ = qs.utils.download_returns(ticker)
stock_
# Out:
# Date
# 1998-07-22 00:00:00+02:00         NaN
# 1998-07-23 00:00:00+02:00   -0.044056
# 1998-07-24 00:00:00+02:00   -0.004121
# 1998-07-27 00:00:00+02:00   -0.028917
# 1998-07-28 00:00:00+02:00   -0.023836
# 1998-07-29 00:00:00+02:00    0.024418
# 1998-07-30 00:00:00+02:00    0.018726
# 1998-07-31 00:00:00+02:00    0.000000
# 1998-08-03 00:00:00+02:00   -0.084377
# 1998-08-04 00:00:00+02:00    0.003641
# 1998-08-05 00:00:00+02:00    0.004552
# 1998-08-06 00:00:00+02:00   -0.020372
# 1998-08-07 00:00:00+02:00    0.000000
# 1998-08-10 00:00:00+02:00   -0.028168
# 1998-08-11 00:00:00+02:00   -0.077954
# 1998-08-12 00:00:00+02:00    0.006190
# 1998-08-13 00:00:00+02:00   -0.008717
# 1998-08-14 00:00:00+02:00    0.043928
# 1998-08-17 00:00:00+02:00   -0.014833
# 1998-08-18 00:00:00+02:00    0.025121
# 1998-08-19 00:00:00+02:00    0.009798
# 1998-08-20 00:00:00+02:00   -0.014564
# 1998-08-21 00:00:00+02:00   -0.054185
# 1998-08-24 00:00:00+02:00    0.002607
# ...

# %% [markdown]
# __show sharpe ratio__

# %%
qs.stats.sharpe(stock_)
# Out:
# 0.3265193830341266

# %% [markdown]
# __or using extend_pandas()__

# %%
stock_.sharpe()
# Out:
# 0.3265193830341266

# %% [markdown]
# __Visualize stock performance__

# %%
qs.plots.snapshot(stock_, title='Stock Performance', show=True)
